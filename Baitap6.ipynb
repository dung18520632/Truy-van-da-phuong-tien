# %% [markdown]
# <a href="https://colab.research.google.com/github/dung18520632/Truy-van-da-phuong-tien/blob/main/Baitap6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import urllib.request
urllib.request.urlretrieve("https://archive.ics.uci.edu/ml/machine-learning-databases/20newsgroups-mld/20_newsgroups.tar.gz","20_newsgroups.tar.gz")
# Out:
# ('20_newsgroups.tar.gz', <http.client.HTTPMessage at 0x7f3ebc0f21d0>)

# %%
from os.path import isfile, join
import string
from os import listdir

# %%
my_path = '/content/20_newsgroups'

#creating a list of folder names to make valid pathnames later
folders = [f for f in listdir(my_path)]

# %%
folders
# Out:
# ['misc.forsale',
#  'alt.atheism',
#  'comp.os.ms-windows.misc',
#  'comp.windows.x',
#  'rec.sport.baseball',
#  'sci.med',
#  'talk.religion.misc',
#  'comp.sys.mac.hardware',
#  'rec.autos',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'sci.electronics',
#  'comp.sys.ibm.pc.hardware',
#  'comp.graphics',
#  'talk.politics.guns',
#  'sci.crypt',
#  'soc.religion.christian',
#  'rec.sport.hockey',
#  'sci.space',
#  'rec.motorcycles']

# %%
files = []
for folder_name in folders:
    folder_path = join(my_path, folder_name)
    files.append([f for f in listdir(folder_path)])

# %%
sum(len(files[i]) for i in range(20))
# Out:
# 19997

# %%
pathname_list = []
for fo in range(len(folders)):
    for fi in files[fo]:
        pathname_list.append(join(my_path, join(folders[fo], fi)))

# %%
len(pathname_list)
# Out:
# 19997

# %%
Y = []
for folder_name in folders:
    folder_path = join(my_path, folder_name)
    num_of_files= len(listdir(folder_path))
    for i in range(num_of_files):
        Y.append(folder_name)

# %%
from sklearn.model_selection import train_test_split

# %%
doc_train, doc_test, Y_train, Y_test = train_test_split(pathname_list, Y, random_state=0, test_size=0.25)

# %%
stopwords = ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and', 'any', 'are', "aren't", 'as', 'at',
 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 
 'can', "can't", 'cannot', 'could', "couldn't", 'did', "didn't", 'do', 'does', "doesn't", 'doing', "don't", 'down', 'during',
 'each', 'few', 'for', 'from', 'further', 
 'had', "hadn't", 'has', "hasn't", 'have', "haven't", 'having', 'he', "he'd", "he'll", "he's", 'her', 'here', "here's",
 'hers', 'herself', 'him', 'himself', 'his', 'how', "how's",
 'i', "i'd", "i'll", "i'm", "i've", 'if', 'in', 'into', 'is', "isn't", 'it', "it's", 'its', 'itself',
 "let's", 'me', 'more', 'most', "mustn't", 'my', 'myself',
 'no', 'nor', 'not', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'ought', 'our', 'ours' 'ourselves', 'out', 'over', 'own',
 'same', "shan't", 'she', "she'd", "she'll", "she's", 'should', "shouldn't", 'so', 'some', 'such', 
 'than', 'that',"that's", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', "there's", 'these', 'they', "they'd", 
 "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 'very', 
 'was', "wasn't", 'we', "we'd", "we'll", "we're", "we've", 'were', "weren't", 'what', "what's", 'when', "when's", 'where',
 "where's", 'which', 'while', 'who', "who's", 'whom', 'why', "why's",'will', 'with', "won't", 'would', "wouldn't", 
 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves', 
 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'hundred', 'thousand', '1st', '2nd', '3rd',
 '4th', '5th', '6th', '7th', '8th', '9th', '10th']

# %%
def preprocess(words):
    #we'll make use of python's translate function,that maps one set of characters to another
    #we create an empty mapping table, the third argument allows us to list all of the characters 
    #to remove during the translation process
    
    #first we will try to filter out some  unnecessary data like tabs
    table = str.maketrans('', '', '\t')
    words = [word.translate(table) for word in words]
    
    punctuations = (string.punctuation).replace("'", "") 
    # the character: ' appears in a lot of stopwords and changes meaning of words if removed
    #hence it is removed from the list of symbols that are to be discarded from the documents
    trans_table = str.maketrans('', '', punctuations)
    stripped_words = [word.translate(trans_table) for word in words]
    
    #some white spaces may be added to the list of words, due to the translate function & nature of our documents
    #we remove them below
    words = [str for str in stripped_words if str]
    
    #some words are quoted in the documents & as we have not removed ' to maintain the integrity of some stopwords
    #we try to unquote such words below
    p_words = []
    for word in words:
        if (word[0] and word[len(word)-1] == "'"):
            word = word[1:len(word)-1]
        elif(word[0] == "'"):
            word = word[1:len(word)]
        else:
            word = word
        p_words.append(word)
    
    words = p_words.copy()
        
    #we will also remove just-numeric strings as they do not have any significant meaning in text classification
    words = [word for word in words if not word.isdigit()]
    
    #we will also remove single character strings
    words = [word for word in words if not len(word) == 1]
    
    #after removal of so many characters it may happen that some strings have become blank, we remove those
    words = [str for str in words if str]
    
    #we also normalize the cases of our words
    words = [word.lower() for word in words]
    
    #we try to remove words with only 2 characters
    words = [word for word in words if len(word) > 2]
    
    return words

# %%
def remove_stopwords(words):
    words = [word for word in words if not word in stopwords]
    return words

# %%
def tokenize_sentence(line):
    words = line[0:len(line)-1].strip().split(" ")
    words = preprocess(words)
    words = remove_stopwords(words)
    
    return words

# %%
def remove_metadata(lines):
    for i in range(len(lines)):
        if(lines[i] == '\n'):
            start = i+1
            break
    new_lines = lines[start:]
    return new_lines

# %%
def tokenize(path):
    #load document as a list of lines
    f = open(path, 'r',encoding='cp1252')
    text_lines = f.readlines()
    
    #removing the meta-data at the top of each document
    text_lines = remove_metadata(text_lines)
    
    #initiazing an array to hold all the words in a document
    doc_words = []
    
    #traverse over all the lines and tokenize each one with the help of helper function: tokenize_sentence
    for line in text_lines:
        doc_words.append(tokenize_sentence(line))

    return doc_words

# %%
def flatten(list):
    new_list = []
    for i in list:
        for j in i:
            new_list.append(j)
    return new_list

# %%
len(folders)
# Out:
# 20

# %%
list_of_words = []
for document in doc_train:
        list_of_words.append(flatten(tokenize(document)))

# %%
print(list_of_words[100])
# Out:
# ['article', '1993apr2019563617742guinnessidbsuedu', 'betzgozeridbsuedu', 'andrew', 'betz', 'writes', 'betzgozeridbsuedu', 'brought', 'terminal', 'free', 'state', 'idaho', 'outlaw', 'rights', 'outlaws', 'rights', 'spook', 'fodder', 'fema', 'nsa', 'clinton', 'gore', 'insurrection', 'nsc', 'semtex', 'neptunium', 'terrorist', 'cia', 'mi5', 'mi6', 'kgb', 'deuterium', 'really', 'want', 'trigger', 'scanners', 'move', 'keywords', 'signature', 'start', 'bit', 'trip', 'sig', 'plus', 'every', 'often', 'flag', 'human', 'intervention', 'just', 'sure', 'might', 'serious', 'alan', 'greig', 'janet', 'agreigukacdct', 'dundee', 'institute', 'technology', 'internet', 'agreigdctacuk', 'tel', 'int', 'never', 'underestimate', 'power', 'human', 'stupidity']

# %%
import numpy as np
np_list_of_words = np.asarray(flatten(list_of_words))

# %%
words, counts = np.unique(np_list_of_words, return_counts=True)

# %%
freq, wrds = (list(i) for i in zip(*(sorted(zip(counts, words), reverse=True))))

# %%
dictionary = {}
doc_num = 1
for doc_words in list_of_words:
    #print(doc_words)
    np_doc_words = np.asarray(doc_words)
    w, c = np.unique(np_doc_words, return_counts=True)
    dictionary[doc_num] = {}
    for i in range(len(w)):
        dictionary[doc_num][w[i]] = c[i]
    doc_num = doc_num + 1

# %%
dictionary
# Out:
# {1: {'c5y4t79w3newscsouiucedu': 1,
#   'explain': 1,
#   'extinguished': 1,
#   'george': 1,
#   'greg': 1,
#   'krumins': 1,
#   'majority': 1,
#   'matter': 1,
#   'might': 1,
#   'minority': 1,
#   'nicholls': 1,
#   'nichoolympusdemoncouk': 1,
#   'nichovnetibmcom': 1,
#   'perhaps': 1,
#   'ridiculous': 1,
#   'rights': 2,
#   'talking': 1,
#   'typical': 1,
#   'umm': 1,
#   'veni': 1,
#   'vici': 1,
#   'vidi': 1,
#   'wants': 2,
#   'writes': 1},
#  2: {'1993apr20459036066spectrumxeroxcom': 1,
#   'aaron': 1,
#   "ain't": 2,
#   'ama669373': 1,
#   'article': 1,
#   'assholes': 1,
#   'attidue': 1,
#   'boost': 1,
#   'change': 1,
#   'clad': 1,
#   'cooleyxeroxcom': 1,
#   'disgruntled': 1,
#   'dod564': 1,
#   'doh0000000005': 1,
#   'drivers': 1,
#   'ego': 1,
#   'enjoyment': 1,
#   'exactly': 1,
#   'exist': 1,
#   'find': 1,
#   'gets': 1,
#   'hope': 1,
#   'hottentot': 1,
#   'just': 1,
#   'kidding': 1,
#   'killed': 1,
#   'kind': 1,
#   'lanes': 1,
#   'leather': 1,
#   'look': 1,
#   'many': 1,
#   'motorcyclist': 1,
#   'necesary': 1,
#   'others': 1,
#   'poseur': 1,
#   'poseurs': 1,
#   'pretend': 1,
#   'really': 1,
#   'rebelling': 1,
#   'road': 1,
#   "sesquipedalian's": 1,
#   "steatopygias's": 1,
#   'swear': 1,
#   'swirve': 1,
#   'truely': 1,
#   'volvo': 1,
#   'watch': 1,
#   'wreck': 1,
#   'writes': 1,
#   'zx10': 1},
#  3: {'1qk7kvinnndkdns1nmsuedu': 1,
#   '5mbs': 1,
#   'ability': 1,
#   'access': 1,
#   'accessing': 1,
#   'actually': 1,
#   'add': 3,
#   'added': 2,
#   'adding': 1,
#   'address': 1,
#   'advantage': 1,
#   'allow': 1,
#   'almost': 2,
#   'alone': 1,
#   'along': 1,
#   'anyone': 1,
#   'anywhere': 1,
#   'argue': 1,
#   'article': 1,
#   'asynchronous': 3,
#   'attached': 1,
#   'averages': 1,
#   'away': 2,
#   'back': 1,
#   'becomes': 1,
#   'benefit': 1,
#   'better': 5,
#   'bgrubbdantenmsuedu': 1,
#   'blows': 2,
#   'blue': 1,
#   'bottleneck': 1,
#   'bought': 2,
#   'bunch': 1,
#   'bus': 4,
#   'buying': 1,
#   'cache': 1,
#   'capability': 1,
#   'card': 2,
#   'carefully': 1,
#   'cart': 1,
#   'cga': 1,
#   'cheaper': 1,
#   'check': 1,
#   'choice': 2,
#   'come': 1,
#   'comes': 3,
#   'coming': 1,
#   'common': 3,
#   'compared': 1,
#   'computer': 1,
#   'concurrently': 1,
#   'connection': 2,
#   'connor': 2,
#   'controller': 1,
#   'cost': 2,
#   'currently': 1,
#   'data': 6,
#   'dead': 2,
#   'decisions': 1,
#   'device': 2,
#   'devices': 4,
#   'different': 2,
#   'dollars': 1,
#   'drive': 18,
#   'drives': 9,
#   'easily': 1,
#   'ega': 1,
#   'eisa': 2,
#   'electronics': 1,
#   'exceed': 1,
#   'exclusion': 1,
#   'expandibility': 1,
#   'expensive': 2,
#   'explain': 1,
#   'face': 1,
#   'faster': 3,
#   'favorite': 1,
#   'figure': 1,
#   'file': 1,
#   'find': 3,
#   'first': 1,
#   'following': 1,
#   'fringe': 1,
#   'full': 2,
#   'garbage': 1,
#   'get': 2,
#   'given': 1,
#   'goes': 1,
#   'going': 1,
#   'good': 2,
#   'got': 3,
#   'greg': 2,
#   'grubb': 1,
#   'handier': 1,
#   'hands': 1,
#   'hard': 5,
#   'highway': 1,
#   'home': 2,
#   'hook': 1,
#   'ide': 16,
#   "ide's": 1,
#   'implemented': 1,
#   'implimented': 2,
#   'inherently': 1,
#   'instance': 1,
#   'integrated': 1,
#   'interface': 4,
#   'interfaced': 1,
#   'interfaces': 1,
#   'intrinsically': 2,
#   'investing': 1,
#   'isa': 5,
#   'jumpers': 1,
#   'just': 1,
#   'keep': 1,
#   'know': 2,
#   'lately': 1,
#   'least': 1,
#   'like': 1,
#   'limited': 2,
#   'list': 1,
#   'little': 1,
#   'loaded': 1,
#   'long': 1,
#   'love': 1,
#   'lowest': 1,
#   'mac': 3,
#   'machines': 1,
#   'mainly': 2,
#   'make': 1,
#   'makes': 1,
#   'managing': 3,
#   'many': 3,
#   'matters': 1,
#   'max': 1,
#   'maximum': 1,
#   'maxtor': 1,
#   'maybe': 1,
#   'mechanisim': 1,
#   'mechanisims': 1,
#   'mechanism': 1,
#   'medium': 2,
#   'meg': 7,
#   'megssec': 3,
#   'method': 1,
#   'millions': 1,
#   'mine': 1,
#   'mode': 3,
#   'money': 1,
#   'moving': 1,
#   'multi': 1,
#   'multiple': 1,
#   'multitasking': 3,
#   'must': 1,
#   'mutual': 1,
#   'mysterious': 1,
#   'name': 1,
#   'nature': 3,
#   'neat': 1,
#   'necessary': 2,
#   'new': 1,
#   'nice': 2,
#   'nobody': 1,
#   'noticable': 1,
#   'notice': 1,
#   'noticed': 1,
#   'now': 1,
#   'older': 2,
#   'original': 3,
#   "os's": 1,
#   'paid': 1,
#   'part': 1,
#   'partial': 1,
#   "pc's": 2,
#   'pcs': 1,
#   'perform': 1,
#   'pga': 1,
#   'plenty': 1,
#   'plug': 1,
#   'point': 2,
#   'poor': 1,
#   'pretty': 1,
#   'price': 2,
#   'problem': 3,
#   'put': 4,
#   'quantum': 1,
#   'question': 1,
#   'quite': 1,
#   'quote': 1,
#   'rate': 1,
#   'rates': 1,
#   'read': 2,
#   'recently': 1,
#   'relatively': 1,
#   'rocketsuunetcsnxelcomshaw': 1,
#   'said': 1,
#   'says': 1,
#   'scsi': 27,
#   'scsi1': 1,
#   'scsi2': 4,
#   'seen': 1,
#   'sence': 1,
#   'servers': 1,
#   'set': 1,
#   'setting': 1,
#   'setup': 1,
#   'sgi': 1,
#   'shaw': 1,
#   'simply': 2,
#   'single': 4,
#   'sized': 1,
#   'slave': 1,
#   'smith': 1,
#   'sparc': 1,
#   'specs': 1,
#   'specsheet': 1,
#   'standard': 3,
#   'start': 1,
#   'still': 1,
#   'stood': 1,
#   'storage': 1,
#   'street': 1,
#   'sun': 1,
#   "sun's": 1,
#   'switch': 2,
#   'system': 4,
#   'takes': 2,
#   'talking': 3,
#   'tape': 1,
#   'tasking': 1,
#   'termination': 1,
#   'thing': 3,
#   'things': 1,
#   'think': 1,
#   'thought': 1,
#   'thousands': 1,
#   'throughput': 1,
#   'till': 1,
#   'time': 4,
#   'together': 1,
#   'tooshawfeanorxelcom': 1,
#   'transfer': 2,
#   'types': 1,
#   'ugly': 1,
#   'unix': 2,
#   'use': 3,
#   'used': 3,
#   'uses': 1,
#   'view': 1,
#   'vlb': 2,
#   'vlbide': 2,
#   'want': 2,
#   'water': 1,
#   'way': 1,
#   'wayne': 1,
#   'well': 1,
#   'whatever': 1,
#   'whether': 1,
#   'windogs': 1,
#   'window': 1,
#   'wlsmithvalveheartrriuwoca': 1,
#   'work': 2,
#   'works': 1,
#   'workstation': 1,
#   'workstations': 1,
#   'worth': 2,
#   'writes': 1,
#   'wrote': 1,
#   'years': 1},
#  4: {'beyond': 1,
#   'black': 3,
#   'bodies': 1,
#   'boundaries': 1,
#   'bruce': 1,
#   'called': 1,
#   'change': 1,
#   'desitter': 1,
#   'event': 1,
#   'existed': 1,
#   'govern': 1,
#   'hawking': 1,
#   'hole': 2,
#   'holes': 1,
#   'horizon': 1,
#   'hyperspace': 1,
#   'knows': 1,
#   'laws': 2,
#   'like': 2,
#   'lines': 1,
#   'look': 1,
#   'looked': 1,
#   'nessage': 1,
#   'nice': 1,
#   'noone': 1,
#   'note': 1,
#   'open': 1,
#   'outside': 2,
#   'parallel': 1,
#   'posit': 1,
#   'purist': 1,
#   'radiation': 1,
#   'salem': 1,
#   'something': 1,
#   'space': 2,
#   'spacetime': 1,
#   'speculation': 1,
#   'subject': 1,
#   'suppose': 1,
#   'universe': 5,
#   'universes': 1,
#   'way': 1,
#   'whatever': 1,
#   'whether': 1,
#   'within': 1,
#   'wonder': 1},
#  5: {'0001something': 1,
#   '0001xxxx': 2,
#   '18k': 1,
#   '32m': 1,
#   'absolutely': 1,
#   'address': 5,
#   'allow': 1,
#   'also': 1,
#   'alter': 1,
#   'always': 2,
#   'american': 1,
#   'another': 1,
#   'anything': 1,
#   'application': 4,
#   'att': 1,
#   'autoexecbat': 2,
#   'autoexecbatwith': 1,
#   'background': 1,
#   'bell': 1,
#   'bios': 1,
#   'boundary': 1,
#   'bring': 1,
#   'buffers30': 1,
#   'cache': 1,
#   'came': 1,
#   'chu': 1,
#   'click': 1,
#   'clone': 1,
#   'cmos': 1,
#   'commented': 1,
#   'configsys': 1,
#   'crossing': 1,
#   'day': 1,
#   'desktop': 2,
#   'devicecdoshimemsys': 1,
#   'devicecwindowsemm386exe': 1,
#   'different': 1,
#   'doshighumb': 1,
#   'driver': 1,
#   'emm386': 1,
#   'error': 3,
#   'every': 1,
#   'excel': 4,
#   'failure': 1,
#   'fault': 2,
#   'file': 3,
#   'files30': 1,
#   'first': 1,
#   'flagged': 1,
#   'followed': 1,
#   'following': 1,
#   'frustrated': 1,
#   'general': 1,
#   'get': 1,
#   'getting': 1,
#   'help': 1,
#   'holmdel': 1,
#   'idea': 2,
#   'increasing': 1,
#   'install': 1,
#   'installation': 1,
#   'installed': 2,
#   'know': 1,
#   'labs': 1,
#   'like': 2,
#   'load': 1,
#   'loaded': 1,
#   'looks': 1,
#   'manufacture': 1,
#   'mean': 1,
#   'means': 1,
#   'megatrend': 1,
#   'memory': 1,
#   'messages': 1,
#   'middle': 1,
#   'mouse': 1,
#   'nav': 1,
#   'ndw': 1,
#   'ndwexe': 2,
#   'newly': 1,
#   'noems': 1,
#   'norton': 1,
#   'number': 1,
#   'permanent': 1,
#   'place': 1,
#   'please': 1,
#   'problem': 5,
#   'proceed': 1,
#   'programs': 1,
#   'protection': 1,
#   'provided': 1,
#   'ram': 2,
#   'read': 1,
#   'reply': 1,
#   'right': 1,
#   'run': 1,
#   'running': 4,
#   'screen': 2,
#   'segment': 1,
#   'selection': 1,
#   'set': 1,
#   'setup': 1,
#   'size': 1,
#   'smartdrvexe': 1,
#   'something': 1,
#   'stack': 1,
#   'stack9256': 1,
#   'started': 1,
#   'state': 1,
#   'steve': 1,
#   'suggestion': 1,
#   'suppose': 1,
#   'swap': 1,
#   'tc1024drv': 2,
#   'telling': 1,
#   'tried': 1,
#   'try': 2,
#   'tsr': 1,
#   'using': 1,
#   'various': 1,
#   'version': 1,
#   'vga': 1,
#   'wait': 1,
#   'willing': 1,
#   'win31': 3,
#   'windows': 2,
#   'write': 1,
#   'xxxx': 1},
#  6: {'absolutely': 1,
#   'acts': 1,
#   'admit': 1,
#   'animals': 1,
#   'approximate': 1,
#   'argue': 1,
#   'automobiles': 1,
#   'beings': 2,
#   'bothers': 1,
#   'callison': 1,
#   'car': 1,
#   'cars': 1,
#   'chaffee': 1,
#   'committing': 1,
#   'completely': 1,
#   'death': 1,
#   'else': 1,
#   'everything': 1,
#   'fact': 1,
#   'feel': 1,
#   'flesh': 1,
#   'going': 1,
#   'human': 3,
#   'jim': 1,
#   'just': 1,
#   'less': 1,
#   'many': 1,
#   'mchaffeedclnxt07': 1,
#   'mean': 1,
#   'mention': 1,
#   'mere': 1,
#   'michael': 1,
#   'money': 1,
#   'moves': 1,
#   'number': 1,
#   'people': 1,
#   'piece': 1,
#   'rape': 1,
#   'realise': 1,
#   'right': 1,
#   'rights': 1,
#   'scratch': 1,
#   'scum': 1,
#   'senseless': 1,
#   'shape': 1,
#   'significantly': 1,
#   'stealing': 1,
#   'submit': 1,
#   'terms': 1,
#   'think': 1,
#   'track': 1,
#   'value': 1,
#   'valued': 1,
#   'violence': 1,
#   'wayyou': 1,
#   'writes': 1},
#  7: {'absurd': 1,
#   'albeit': 1,
#   'alfredo': 1,
#   'allow': 1,
#   'alomar': 2,
#   'already': 1,
#   'always': 3,
#   'aptitudes': 1,
#   'arguments': 1,
#   'baerga': 1,
#   'baseball': 1,
#   'beleive': 1,
#   'best': 3,
#   'better': 4,
#   'bring': 1,
#   'btw': 1,
#   'c5sfveaqmurdochaccvirginiaedu': 1,
#   'call': 1,
#   'carlos': 1,
#   'carter': 1,
#   'cases': 1,
#   'chicago': 1,
#   'choose': 1,
#   'claim': 1,
#   'clearly': 1,
#   'clemens': 2,
#   'close': 1,
#   'completely': 1,
#   'components': 1,
#   'conceivable': 1,
#   'contribute': 1,
#   'contributed': 1,
#   'cordially': 1,
#   'david': 1,
#   'define': 2,
#   'defining': 1,
#   'definition': 1,
#   'definitions': 1,
#   'depending': 1,
#   'detroit': 1,
#   'difference': 1,
#   'differences': 1,
#   'drw3ldelmarvaevscvirginiaedu': 1,
#   'effort': 1,
#   'else': 1,
#   'error': 1,
#   'estimate': 1,
#   'ever': 1,
#   'every': 1,
#   'failure': 2,
#   'fielder': 2,
#   'find': 2,
#   'game': 2,
#   'given': 1,
#   'goal': 1,
#   'good': 1,
#   'great': 1,
#   'griffin': 2,
#   'guzman': 1,
#   'hairs': 1,
#   'help': 1,
#   'henke': 1,
#   'herm': 1,
#   'imperfectly': 1,
#   'improve': 1,
#   'individual': 4,
#   'individuals': 1,
#   'isolate': 1,
#   'jeff': 1,
#   'joe': 1,
#   'john': 1,
#   'juan': 1,
#   'judge': 1,
#   'just': 1,
#   'larkin': 3,
#   'last': 2,
#   'least': 2,
#   'lee': 1,
#   'less': 1,
#   'lesser': 2,
#   'little': 2,
#   'look': 1,
#   'lost': 1,
#   'luis': 1,
#   'made': 1,
#   'make': 1,
#   'many': 1,
#   'maynardramseycslaurentianca': 1,
#   'mean': 1,
#   'measure': 2,
#   'might': 6,
#   'morons': 1,
#   'morris': 2,
#   'needs': 3,
#   'now': 1,
#   'olerud': 4,
#   'others': 1,
#   'performers': 1,
#   'played': 1,
#   'player': 4,
#   'pretty': 1,
#   'purpose': 1,
#   'quality': 4,
#   'rank': 1,
#   'ranking': 1,
#   'reading': 1,
#   'really': 1,
#   'reardon': 1,
#   'replace': 1,
#   'rivera': 1,
#   'robby': 2,
#   'robert': 1,
#   'roger': 1,
#   'say': 2,
#   'since': 1,
#   'single': 1,
#   'someplace': 1,
#   'something': 2,
#   'split': 1,
#   'success': 2,
#   'suggests': 1,
#   'sum': 1,
#   'surrounded': 1,
#   'talents': 1,
#   'team': 14,
#   'teammates': 1,
#   'things': 1,
#   'thomas': 3,
#   'time': 1,
#   'tom': 1,
#   'toronto': 1,
#   'trying': 1,
#   'vary': 1,
#   'walker': 1,
#   'well': 1,
#   'win': 2,
#   'winning': 1,
#   'winninham': 1,
#   'won': 7,
#   'writes': 1,
#   'year': 2,
#   'yet': 1},
#  8: {'15440optilinkcom': 1,
#   'article': 2,
#   'associate': 2,
#   'baseball': 1,
#   'based': 1,
#   'becuase': 1,
#   'c5navnf3pmurdochaccvirginiaedu': 1,
#   'chances': 1,
#   'clayton': 1,
#   'concept': 1,
#   'cramer': 1,
#   'crameroptilinkcom': 1,
#   'created': 1,
#   'discrimination': 2,
#   'ending': 2,
#   'equal': 1,
#   'etc': 1,
#   'even': 1,
#   'everyday': 1,
#   'fascism': 1,
#   'force': 1,
#   'forced': 1,
#   'game': 1,
#   'greg': 2,
#   'gsh7wfermiclasvirginiaedu': 1,
#   'hennessy': 2,
#   'law': 1,
#   'makes': 1,
#   'men': 1,
#   'now': 1,
#   'others': 1,
#   'park': 1,
#   'people': 3,
#   'process': 1,
#   'public': 1,
#   'qual': 1,
#   'rational': 1,
#   'shopping': 1,
#   'society': 1,
#   'standing': 1,
#   'university': 1,
#   'upon': 1,
#   'virginia': 1,
#   'want': 1,
#   'wish': 1,
#   'women': 1,
#   'work': 1,
#   'writes': 2,
#   'yes': 1},
#  9: {'agree': 1,
#   'ass': 1,
#   'better': 1,
#   'bill': 1,
#   'caps': 1,
#   'clement': 1,
#   'complain': 1,
#   'coverage': 4,
#   'espn': 2,
#   "espn's": 2,
#   'ever': 1,
#   'everybody': 1,
#   'feel': 1,
#   'getting': 1,
#   'going': 1,
#   'great': 1,
#   'hang': 1,
#   'hockey': 2,
#   'hope': 1,
#   'indians': 1,
#   'isles': 1,
#   'jbrownvaxcnsmuskingumedu': 1,
#   'knew': 1,
#   'know': 2,
#   'last': 1,
#   'makes': 1,
#   'mean': 2,
#   'might': 1,
#   'night': 1,
#   'nothing': 1,
#   'ohio': 1,
#   'overtime': 1,
#   'pathetic': 1,
#   'pissed': 1,
#   'really': 2,
#   'regular': 1,
#   'school': 1,
#   'season': 1,
#   'shoot': 1,
#   'shot': 1,
#   'show': 1,
#   'sportscenter': 1,
#   'suck': 2,
#   'sucks': 2,
#   'suggest': 1,
#   'watched': 1,
#   'watching': 1,
#   'worked': 1,
#   'writes': 1},
#  10: {'able': 4,
#   'addition': 1,
#   'aimed': 1,
#   'amanda': 1,
#   'anyone': 1,
#   'anything': 1,
#   'approval': 1,
#   'argument': 1,
#   'arm': 1,
#   'assault': 1,
#   'authorities': 1,
#   'barrier': 1,
#   "bbs's": 1,
#   'believe': 1,
#   'better': 2,
#   'beyond': 1,
#   'borders': 1,
#   'building': 1,
#   'business': 2,
#   'calls': 1,
#   'casebycase': 1,
#   'casual': 1,
#   'catalog': 1,
#   'certainly': 1,
#   'channelit': 1,
#   'clients': 1,
#   'clipper': 4,
#   'communication': 1,
#   'companies': 1,
#   'compete': 1,
#   'confession': 1,
#   'confidence': 1,
#   'consider': 1,
#   'contracts': 1,
#   'conversation': 1,
#   'corporation': 1,
#   'cost': 1,
#   'course': 1,
#   'crypto': 3,
#   'cryptophone': 1,
#   'crytographic': 1,
#   'current': 1,
#   'currently': 1,
#   'cylink': 2,
#   'danger': 1,
#   'default': 1,
#   'department': 1,
#   'des': 1,
#   'disappeared': 1,
#   'dissident': 1,
#   'distracts': 1,
#   'doctors': 1,
#   'eavesdropping': 1,
#   'electronic': 1,
#   'electronically': 1,
#   'email': 2,
#   'emboldens': 1,
#   'engage': 1,
#   'enhanced': 1,
#   'enough': 1,
#   'especially': 1,
#   'even': 2,
#   'example': 2,
#   'far': 1,
#   'favorite': 1,
#   'feds': 1,
#   'feeling': 1,
#   'firms': 1,
#   'first': 1,
#   'free': 1,
#   'freebie': 1,
#   'friends': 1,
#   'get': 2,
#   'good': 1,
#   'groups': 1,
#   'hand': 2,
#   'hear': 1,
#   'hide': 1,
#   'infeasible': 1,
#   'information': 1,
#   'intercon': 1,
#   'international': 1,
#   'irrelevant': 1,
#   'itar': 1,
#   'japanese': 1,
#   'just': 2,
#   'kinds': 1,
#   'knows': 1,
#   'large': 1,
#   'lawyers': 1,
#   'leg': 1,
#   'less': 1,
#   'like': 1,
#   'listening': 1,
#   'look': 1,
#   'ludicrous': 1,
#   'mail': 1,
#   'mailorder': 1,
#   'maintain': 1,
#   'market': 3,
#   'markets': 1,
#   'mass': 1,
#   'material': 1,
#   'metzger': 1,
#   'mode': 1,
#   'much': 1,
#   'needs': 1,
#   'net': 1,
#   'networking': 1,
#   'news': 1,
#   'none': 1,
#   'nothing': 2,
#   'now': 4,
#   'number': 2,
#   'obviously': 1,
#   'old': 1,
#   'opinions': 1,
#   'order': 1,
#   'overdrive': 1,
#   'overseas': 1,
#   'part': 1,
#   'patients': 1,
#   'pem': 1,
#   'per': 1,
#   'perry': 1,
#   'phone': 1,
#   'phones': 1,
#   'pkcs': 1,
#   'place': 1,
#   'plenty': 1,
#   'pmetzgersnarkshearsoncom': 1,
#   'point': 1,
#   'political': 1,
#   'presents': 1,
#   'prevents': 1,
#   'priests': 1,
#   'privacy': 1,
#   'products': 2,
#   'providing': 1,
#   'put': 2,
#   'quo': 1,
#   'real': 1,
#   'restrictions': 4,
#   'result': 1,
#   'rifle': 1,
#   'right': 3,
#   'safe': 1,
#   'scared': 1,
#   'scheme': 1,
#   'scrambler': 1,
#   'secure': 1,
#   'security': 1,
#   'see': 1,
#   'serious': 1,
#   'share': 1,
#   'ship': 1,
#   'shitless': 1,
#   'sign': 1,
#   'simple': 1,
#   'simply': 1,
#   'slightly': 1,
#   'society': 2,
#   'software': 3,
#   'sort': 2,
#   'state': 1,
#   'status': 1,
#   'still': 1,
#   'strong': 1,
#   'sure': 1,
#   'systems': 3,
#   'talk': 3,
#   'tapped': 1,
#   'theoretical': 1,
#   'theory': 1,
#   'though': 1,
#   'today': 1,
#   'tool': 1,
#   'trade': 1,
#   'transact': 1,
#   'trying': 3,
#   'turn': 1,
#   'understand': 1,
#   'usa': 2,
#   'use': 2,
#   'using': 1,
#   'utter': 1,
#   'vendor': 1,
#   'voice': 1,
#   'walker': 1,
#   'want': 7,
#   'well': 2,
#   'whatever': 1,
#   'without': 1,
#   'work': 1,
#   'working': 2,
#   'worldwide': 1,
#   'worried': 1,
#   'writes': 1,
#   'years': 1,
#   'yet': 1},
#  11: {'advice': 1,
#   'beav': 1,
#   'beavington': 1,
#   'brains': 1,
#   'dod9733': 1,
#   'duke': 1,
#   'edu': 1,
#   'either': 1,
#   'employer': 1,
#   'flames': 1,
#   'hope': 1,
#   'idea': 1,
#   'mbeavingbnrca': 1,
#   'mike': 1,
#   'spell': 1,
#   'student': 1,
#   'take': 1,
#   'talking': 1,
#   'tuition': 1,
#   'v65sabre': 1,
#   'wasting': 1,
#   'whining': 1,
#   'wuit': 1},
#  12: {'1r54toohaccessdigexnet': 1,
#   'advantage': 1,
#   'article': 1,
#   'ask': 1,
#   'assume': 1,
#   'better': 1,
#   'big': 1,
#   'built': 1,
#   'buy': 1,
#   'cape': 1,
#   'cheap': 1,
#   'comparable': 1,
#   'cooperating': 1,
#   'cost': 1,
#   'dennis': 1,
#   'dennisnecscommmotcom': 1,
#   'different': 1,
#   'equip': 1,
#   'except': 1,
#   'found': 1,
#   'handled': 2,
#   'heard': 1,
#   'invest': 1,
#   'just': 1,
#   'kazakstan': 1,
#   'know': 1,
#   'kourou': 1,
#   "ksc's": 1,
#   'land': 1,
#   'last': 1,
#   'later': 1,
#   'launch': 2,
#   'launches': 1,
#   'like': 2,
#   'lockheed': 1,
#   'long': 2,
#   'looked': 1,
#   'looks': 1,
#   'lot': 2,
#   'major': 1,
#   'malfunction': 1,
#   'market': 1,
#   'may': 1,
#   'maybe': 1,
#   'message': 1,
#   'might': 1,
#   'mobile': 1,
#   'motorola': 1,
#   'newer': 1,
#   'newkirk': 1,
#   'nothing': 1,
#   'now': 2,
#   'pads': 1,
#   'pat': 1,
#   'pick': 1,
#   'place': 1,
#   'possibilities': 1,
#   'prbaccessdigexcom': 1,
#   'probably': 2,
#   'products': 1,
#   'propose': 1,
#   'proton': 3,
#   'question': 1,
#   'russia': 2,
#   'russian': 1,
#   'russians': 1,
#   'schaumburg': 1,
#   'sector': 1,
#   'seems': 1,
#   'since': 2,
#   'something': 1,
#   'spare': 1,
#   'spot': 1,
#   'still': 1,
#   'storables': 1,
#   'story': 1,
#   'suppose': 1,
#   'systems': 2,
#   'take': 1,
#   'think': 1,
#   'trouble': 1,
#   'unprofitable': 1,
#   'uses': 1,
#   'using': 1,
#   'vandenberg': 1,
#   'well': 1,
#   'wide': 1,
#   'without': 1,
#   'world': 1,
#   'writes': 1,
#   'years': 1,
#   'yes': 1,
#   'york': 1,
#   'zenit': 1},
#  13: {'access': 1,
#   'advance': 1,
#   'anybody': 1,
#   'apt': 1,
#   'best': 1,
#   'contract': 1,
#   'design': 1,
#   'encryption': 1,
#   'facinated': 1,
#   'get': 1,
#   'govenment': 1,
#   'group': 1,
#   'heard': 1,
#   'houston': 1,
#   'hupp': 1,
#   'implamentation': 1,
#   'internet': 1,
#   'jeff': 1,
#   'jhuppshockwavewinnet': 1,
#   'know': 1,
#   'medowglen': 1,
#   'might': 1,
#   'msdos': 1,
#   'net': 1,
#   'network': 1,
#   'new': 1,
#   'news': 1,
#   'nifty': 1,
#   'novell': 1,
#   'pgp': 1,
#   'program': 2,
#   'programming': 1,
#   'running': 1,
#   'runs': 1,
#   'support': 1,
#   'texas': 1,
#   'thanks': 1,
#   'things': 1,
#   'unix': 2,
#   'uucico': 1,
#   'version': 1,
#   'voice': 1,
#   'windows': 2,
#   'writting': 1,
#   'wsource': 1},
#  14: {'better': 1,
#   'email': 1,
#   'file': 1,
#   'hello': 1,
#   'location': 1,
#   'mleeengsdsuedu': 1,
#   'monitor': 1,
#   'monochrome': 1,
#   'monodriver': 1,
#   'mpeg': 1,
#   'mpegplay': 1,
#   'need': 1,
#   'please': 1,
#   'post': 1,
#   'reading': 1,
#   'request': 1,
#   'run': 1,
#   'running': 1,
#   'thank': 1,
#   'viewer': 1,
#   'xwindows': 1,
#   'yet': 1},
#  15: {'accelerator': 1,
#   'although': 1,
#   'anyone': 1,
#   'appreciate': 1,
#   'appreciated': 1,
#   'article': 1,
#   'based': 1,
#   'belive': 1,
#   'buggy': 1,
#   'card': 2,
#   'despite': 1,
#   'diamond': 2,
#   'drivers': 3,
#   'else': 1,
#   'ever': 1,
#   'experience': 1,
#   'extremely': 1,
#   'fast': 1,
#   'feedback': 1,
#   'find': 2,
#   'fire': 1,
#   'gibson': 1,
#   'graphics': 1,
#   'great': 1,
#   'implementing': 1,
#   'infoworld': 1,
#   'isa': 1,
#   'latest': 1,
#   'location': 1,
#   'lot': 1,
#   'newer': 1,
#   'occasions': 1,
#   'paul': 1,
#   'pointer': 1,
#   'positive': 1,
#   'problems': 1,
#   'purchased': 1,
#   'recently': 1,
#   'review': 1,
#   'romanelli': 1,
#   's90charmmagnusacsohiostateedu': 1,
#   'stealth': 1,
#   'steve': 1,
#   'suggestions': 1,
#   'support': 1,
#   'technical': 1,
#   'upon': 1,
#   'vincent': 1,
#   'vromanelmagnusacsohiostateedu': 1,
#   'windows': 2,
#   'works': 1,
#   'writes': 1},
#  16: {'alou': 1,
#   "alou's": 1,
#   'another': 1,
#   'average': 1,
#   'bag': 1,
#   'batting': 1,
#   'bichette': 1,
#   'boell': 1,
#   'don': 1,
#   'double': 1,
#   'expos': 1,
#   'flyout': 1,
#   'heck': 1,
#   'just': 1,
#   'look': 1,
#   'lost': 1,
#   'martinez': 1,
#   'misplayed': 2,
#   'misplays': 1,
#   'now': 1,
#   'outfield': 1,
#   'oversliding': 1,
#   'player': 1,
#   'run': 1,
#   'single': 1,
#   'tagged': 1,
#   'totally': 1,
#   'triple': 1,
#   'tripleadd': 1,
#   'wonderful': 1},
#  17: {'already': 1,
#   'anderson': 1,
#   'another': 1,
#   'austin': 1,
#   'brinich': 1,
#   'chip': 1,
#   'concern': 1,
#   'cripple': 1,
#   'difficult': 1,
#   'door': 2,
#   'expand': 1,
#   'extremist': 1,
#   'feeling': 1,
#   'flaming': 1,
#   'foisting': 1,
#   'frighteningly': 1,
#   'going': 1,
#   'group': 1,
#   'hightech': 1,
#   'human': 1,
#   "i'at": 1,
#   'idea': 1,
#   'laurie': 1,
#   'least': 1,
#   'libertarian': 1,
#   'loss': 1,
#   'lots': 1,
#   'manufacturers': 1,
#   'market': 1,
#   'metatron': 1,
#   'objections': 1,
#   'ocarina': 1,
#   'paranoid': 1,
#   'people': 1,
#   'performance': 1,
#   'plays': 1,
#   'press': 1,
#   'quite': 1,
#   'result': 1,
#   'right': 1,
#   'salesman': 1,
#   'saying': 1,
#   'sayonara': 1,
#   'sound': 1,
#   'specific': 1,
#   'standard': 1,
#   'steve': 1,
#   'stevebaccessdigexcom': 1,
#   'systems': 1,
#   'technical': 2,
#   'texas': 1,
#   'understand': 2,
#   'worried': 1,
#   'writes': 1,
#   'yet': 1},
#  18: {'abstain': 1,
#   'appear': 1,
#   'arguments': 1,
#   'article': 1,
#   'avoid': 2,
#   'beam': 2,
#   'beautiful': 1,
#   'behold': 1,
#   'beholdest': 1,
#   'best': 1,
#   'biblical': 1,
#   'block': 1,
#   'bones': 1,
#   'brother': 1,
#   "brother's": 1,
#   'celibacy': 1,
#   'celibate': 1,
#   'chance': 1,
#   'christ': 3,
#   'christianity': 2,
#   'christians': 2,
#   'churches': 1,
#   'clear': 2,
#   'completely': 1,
#   'considerest': 1,
#   'contagious': 1,
#   'darin': 1,
#   'day': 1,
#   'dead': 1,
#   'demand': 1,
#   'djohnsoncsucsdedu': 1,
#   'etc': 1,
#   'eye': 4,
#   'forgo': 1,
#   'full': 1,
#   'gay': 1,
#   'help': 1,
#   'heterosexuals': 1,
#   'homeless': 1,
#   'homosexuality': 1,
#   'homosexuals': 1,
#   'hope': 1,
#   'hypocrites': 1,
#   'ignore': 1,
#   'important': 2,
#   'indeed': 1,
#   'interpretation': 1,
#   'johnson': 1,
#   'let': 1,
#   'life': 1,
#   'like': 1,
#   'love': 1,
#   'mat': 2,
#   'may1302311619931569genevarutgersedu': 1,
#   "men's": 1,
#   'might': 1,
#   'mote': 2,
#   'nice': 1,
#   'obligations': 2,
#   'order': 1,
#   'orders': 1,
#   'others': 1,
#   'outward': 1,
#   'people': 1,
#   'pharisees': 1,
#   'pleas': 1,
#   'poor': 2,
#   'protestant': 1,
#   'pull': 1,
#   'quite': 2,
#   'say': 1,
#   'scribes': 1,
#   'sepulchres': 1,
#   'sex': 3,
#   'show': 1,
#   'stumbling': 1,
#   'thine': 3,
#   'thing': 1,
#   'thou': 2,
#   'thought': 1,
#   'thy': 2,
#   'time': 1,
#   'uncleanness': 1,
#   'unto': 2,
#   'walk': 1,
#   'weak': 1,
#   'whited': 1,
#   'willing': 1,
#   'wilt': 1,
#   'within': 1,
#   'woe': 1,
#   'world': 1,
#   'writes': 1,
#   'wrong': 1,
#   'yet': 1},
#  19: {'1r2': 2,
#   'actually': 1,
#   'assume': 2,
#   'assumed': 1,
#   'babbling': 1,
#   'batka': 1,
#   'batkajccmaildaytonsaiccom': 1,
#   'beatles': 1,
#   'caused': 1,
#   'characteristic': 1,
#   'closer': 1,
#   'dark': 1,
#   'dead': 1,
#   'disk': 1,
#   'distance': 1,
#   'distribution': 1,
#   'elvis': 1,
#   'email': 2,
#   'energetic': 1,
#   'energy': 1,
#   'even': 1,
#   'event': 1,
#   'events': 1,
#   'galaxy': 1,
#   'gamma': 2,
#   'guessed': 1,
#   'happening': 1,
#   'home': 1,
#   'idle': 1,
#   'incorrect': 1,
#   'inhibits': 1,
#   'jbatkadesirewrightedu': 1,
#   'jim': 1,
#   'just': 1,
#   'law': 2,
#   'less': 1,
#   'long': 1,
#   'material': 1,
#   'matter': 1,
#   'minute': 1,
#   'minutes': 1,
#   'much': 2,
#   'possible': 1,
#   'propagation': 2,
#   'ray': 1,
#   'rays': 1,
#   'seeing': 1,
#   'shorter': 1,
#   'submarine': 1,
#   'thickness': 1,
#   'time': 1,
#   'unknown': 1,
#   'work': 1,
#   'years': 1,
#   'yellow': 1},
#  20: {'1993may141630441stsciedu': 1,
#   '1t30fustraccessdigexnet': 1,
#   'agency': 1,
#   'article': 2,
#   'belongs': 1,
#   'bring': 1,
#   'buck': 2,
#   'bucks': 3,
#   'case': 1,
#   'charge': 2,
#   'claim': 1,
#   'classified': 1,
#   'coming': 3,
#   'company': 3,
#   'cost': 1,
#   'data': 9,
#   'dempsey': 1,
#   'dempseystsciedu': 1,
#   'dollars': 1,
#   'done': 1,
#   'ever': 1,
#   'everything': 1,
#   'fly': 2,
#   'funding': 1,
#   'gathered': 1,
#   'good': 1,
#   'government': 2,
#   'guys': 1,
#   'hereyou': 1,
#   'however': 2,
#   'indeed': 1,
#   'internal': 2,
#   'just': 2,
#   'keep': 2,
#   'keeping': 1,
#   'know': 1,
#   'law': 2,
#   'legal': 1,
#   'library': 1,
#   'like': 1,
#   'live': 1,
#   'maintain': 1,
#   'makes': 2,
#   'may': 3,
#   'mean': 1,
#   'missing': 1,
#   'national': 1,
#   'nih': 1,
#   'now': 1,
#   'operation': 1,
#   'operations': 1,
#   'pat': 1,
#   'people': 1,
#   'photocoppy': 1,
#   'point': 1,
#   'politics': 3,
#   'prbaccessdigexnet': 1,
#   'property': 1,
#   'proprietary': 1,
#   'proprietory': 1,
#   'proven': 1,
#   'quarters': 1,
#   'raw': 1,
#   'real': 1,
#   'recover': 1,
#   'regarding': 1,
#   'regular': 1,
#   'right': 2,
#   'road': 1,
#   'rocket': 1,
#   'rogers': 2,
#   'roll': 1,
#   'rules': 1,
#   'run': 1,
#   'safeguard': 1,
#   'said': 1,
#   'saw': 1,
#   'saying': 1,
#   'science': 2,
#   'security': 1,
#   'ships': 1,
#   'something': 1,
#   'spacecraft': 1,
#   'spent': 1,
#   'still': 1,
#   'studies': 1,
#   'study': 1,
#   'stuff': 3,
#   'supported': 2,
#   'swept': 1,
#   'takes': 1,
#   'tax': 1,
#   "thev'e": 1,
#   'think': 1,
#   'time': 1,
#   'true': 1,
#   'umbrella': 1,
#   'unfortunately': 1,
#   'unless': 1,
#   'wait': 1,
#   'well': 1,
#   'world': 1,
#   'writes': 2,
#   'year': 1,
#   'yes': 1},
#  21: {'1993apr2423374226839lehmancom': 1,
#   'absolutely': 1,
#   'access': 2,
#   'around': 1,
#   'array': 1,
#   'article': 1,
#   'basic': 1,
#   'behind': 1,
#   'blame': 1,
#   'care': 1,
#   'communications': 1,
#   'completely': 1,
#   'decide': 1,
#   'defeat': 1,
#   'deny': 1,
#   'device': 1,
#   'directional': 1,
#   'electricallynoisy': 1,
#   'expensive': 1,
#   'get': 1,
#   'government': 1,
#   'hell': 1,
#   'hughes': 1,
#   'idea': 1,
#   'jammer': 1,
#   'just': 1,
#   'likely': 1,
#   'make': 1,
#   'manpower': 1,
#   'maybe': 1,
#   'metzger': 1,
#   'mine': 1,
#   'money': 1,
#   'murder': 1,
#   'next': 1,
#   'noted': 1,
#   'opinions': 1,
#   'perry': 1,
#   'phased': 1,
#   'pmetzgersnarkshearsoncom': 1,
#   'remember': 1,
#   'scheme': 1,
#   'security': 1,
#   'sensor': 1,
#   'set': 1,
#   'spark': 1,
#   'state': 1,
#   'system': 1,
#   'systems': 1,
#   'time': 1,
#   'true': 1,
#   'university': 1,
#   'waco': 1,
#   'whugheslonestarutsaedu': 1,
#   'william': 1,
#   'worth': 1,
#   'writes': 2},
#  22: {'aaverage': 1,
#   'abbreviation': 1,
#   'add': 1,
#   'along': 1,
#   'anything': 1,
#   'applicable': 1,
#   'appreciate': 1,
#   'april': 1,
#   'argument': 1,
#   'available': 1,
#   'avoid': 1,
#   'awards': 1,
#   'babitt': 1,
#   'baobpslg': 1,
#   'barry': 1,
#   'baseball': 1,
#   'benes': 1,
#   'better': 1,
#   'biff': 1,
#   'bonds': 2,
#   'butler': 1,
#   'bvery': 1,
#   'candidate': 2,
#   'candidates': 1,
#   'category': 1,
#   'choke': 1,
#   'clemens': 1,
#   'come': 1,
#   'cone': 1,
#   'consecutive': 1,
#   'cost': 1,
#   'couple': 1,
#   'curt': 1,
#   'david': 1,
#   'davis': 1,
#   'deer': 1,
#   'def': 1,
#   'defensive': 1,
#   'dibble': 2,
#   'dmartinez': 1,
#   'drabek': 1,
#   'due': 2,
#   'dykstra': 1,
#   'eexcellent': 1,
#   'emartinez': 1,
#   'end': 2,
#   'era': 1,
#   'example': 1,
#   'existence': 1,
#   'farr': 1,
#   'feldstein': 1,
#   'frank': 1,
#   'game': 1,
#   'games': 4,
#   'gary': 1,
#   'gets': 2,
#   'giant': 1,
#   'good': 1,
#   'griffey': 1,
#   'help': 2,
#   'hill': 1,
#   'hrbek': 1,
#   'huckabay': 1,
#   'huge': 1,
#   'ibb': 1,
#   'inflate': 1,
#   'injuries': 1,
#   'injury': 1,
#   'innings': 1,
#   'ist': 2,
#   'jgonzalez': 1,
#   'just': 1,
#   'ken': 1,
#   'kerr': 1,
#   'kevin': 1,
#   'khill': 1,
#   'last': 1,
#   'layers': 1,
#   'league': 6,
#   'left': 1,
#   'liebe': 1,
#   'lines': 1,
#   'lips': 1,
#   'list': 1,
#   'listed': 1,
#   'living': 1,
#   'long': 1,
#   'love': 1,
#   'lundy': 1,
#   'mcgriff': 1,
#   'mcgwire': 1,
#   'mein': 1,
#   "mid90's": 1,
#   'minutes': 1,
#   'missed': 1,
#   'mussina': 1,
#   'mvp': 4,
#   'name': 2,
#   'new': 1,
#   'next': 2,
#   'nohitter': 1,
#   'now': 1,
#   'ones': 1,
#   'oooooo': 1,
#   'order': 1,
#   'others': 1,
#   'parallel': 1,
#   'perfect': 1,
#   'performance': 1,
#   "perot's": 1,
#   'pitched': 1,
#   'pitchers': 2,
#   'played': 1,
#   'players': 4,
#   'playoff': 1,
#   'please': 4,
#   'pocoroba': 1,
#   'poor': 1,
#   'position': 1,
#   'possibility': 1,
#   'posts': 1,
#   'ppoor': 1,
#   'quoting': 1,
#   'ralomar': 1,
#   'rbi': 1,
#   'record': 1,
#   'regular': 1,
#   'reply': 2,
#   'request': 1,
#   'rijo': 1,
#   'rob': 1,
#   'salaries': 1,
#   'sandberg': 1,
#   'sat': 1,
#   'schatz': 1,
#   'schilling': 1,
#   'scoreless': 1,
#   'season': 2,
#   'sho': 1,
#   'shooty': 1,
#   'sig': 1,
#   'smoltz': 1,
#   'someone': 1,
#   'sounds': 1,
#   'soweit': 1,
#   'span': 1,
#   'spot': 1,
#   'standings': 1,
#   'start': 1,
#   'stats': 1,
#   'sucking': 1,
#   'tabletop': 1,
#   'take': 2,
#   'team': 2,
#   'teams': 1,
#   'tewksbury': 1,
#   'thanks': 3,
#   'thomas': 1,
#   'threw': 2,
#   'time': 3,
#   'tomlin': 1,
#   'traded': 1,
#   'universes': 1,
#   'unsere': 1,
#   'ventura': 1,
#   'vorbei': 1,
#   'vote': 3,
#   'voting': 1,
#   'vvery': 1,
#   'want': 1,
#   'winners': 1,
#   'year': 2,
#   "year's": 2,
#   'zavatson': 1},
#  23: {'1qu8ud2hdsunbocsmqeduau': 1,
#   'addressing': 1,
#   'also': 1,
#   'always': 1,
#   'another': 1,
#   'architecture': 1,
#   'architectures': 1,
#   'arguing': 1,
#   'article': 3,
#   'authority': 1,
#   'away': 1,
#   'best': 1,
#   'better': 1,
#   'books': 1,
#   'brian': 1,
#   'bye': 1,
#   'c5o1yqm34csienctuedutw': 1,
#   'c5rx8bkzpecftorontoedu': 1,
#   'circuit': 1,
#   'cisc': 4,
#   'clearly': 1,
#   'clock': 1,
#   'complex': 1,
#   'computer': 2,
#   'costly': 1,
#   'cpu': 1,
#   'cpus': 1,
#   'dear': 1,
#   'difference': 1,
#   'either': 1,
#   'eugenempcemqeduau': 1,
#   'even': 1,
#   'everyone': 1,
#   'first': 1,
#   'friend': 1,
#   'generation': 1,
#   'ghhwang': 1,
#   'ghhwangcsienctuedutw': 1,
#   'high': 1,
#   'hmm': 1,
#   'hypercube': 1,
#   'increase': 1,
#   'information': 1,
#   'instruction': 5,
#   'intel': 2,
#   'just': 1,
#   'large': 1,
#   'lee': 1,
#   'leebrecftorontoedu': 1,
#   'like': 2,
#   'longer': 1,
#   'look': 1,
#   'maybe': 1,
#   'mean': 1,
#   'means': 1,
#   'mips': 1,
#   'modes': 1,
#   'order': 1,
#   'orthogonal': 1,
#   'outsell': 1,
#   'pentium': 3,
#   'performance': 1,
#   'personally': 1,
#   'quantities': 1,
#   'rate': 1,
#   'rather': 1,
#   'read': 1,
#   'reading': 2,
#   'reduce': 1,
#   'reduced': 2,
#   'remember': 3,
#   'reordered': 1,
#   'risc': 8,
#   'riscs': 2,
#   'set': 3,
#   'sets': 1,
#   'small': 1,
#   'sold': 1,
#   'story': 1,
#   'superscallar': 1,
#   'supposed': 1,
#   't800': 1,
#   'take': 1,
#   'theoretically': 1,
#   'think': 1,
#   'usually': 1,
#   'win': 1,
#   'writes': 3,
#   'years': 1},
#  24: {'afd': 1,
#   'aoct': 1,
#   'appreciated': 1,
#   'bultman': 1,
#   'bultmandgwrwsnl': 1,
#   'conversion': 1,
#   'cube': 1,
#   'cylinder': 1,
#   'dienst': 1,
#   'directly': 1,
#   'double': 1,
#   'email': 1,
#   'gert': 2,
#   'get': 1,
#   'getijdewateren': 1,
#   'greatly': 1,
#   'hague': 1,
#   'help': 1,
#   'hexcone': 1,
#   'hls': 2,
#   'hsv': 2,
#   'looking': 1,
#   'mail': 2,
#   'mark': 1,
#   'miss': 1,
#   'netherlands': 1,
#   'newsgroup': 1,
#   'ooo': 2,
#   'personal': 1,
#   'persoonlijk': 1,
#   'phone': 1,
#   'please': 2,
#   'postbus': 1,
#   'rgb': 2,
#   'rgbhsv': 1,
#   'rijkswaterstaat': 1,
#   'routines': 1,
#   'site': 1,
#   'snail': 1,
#   'wil': 1},
#  25: {'100mm': 1,
#   '24mm': 1,
#   '35rc': 1,
#   '42mm': 1,
#   'actually': 1,
#   'addedcall': 1,
#   'advance': 1,
#   'alan': 1,
#   'alpex': 1,
#   'alqiclabscnraincom': 1,
#   'although': 1,
#   'another': 1,
#   'articulated': 1,
#   'auto': 4,
#   'back': 2,
#   'beautifully': 1,
#   'bellows': 1,
#   'best': 1,
#   'bodies': 1,
#   'body': 2,
#   'box': 1,
#   'built': 2,
#   'call': 2,
#   'camera': 4,
#   'cameras': 2,
#   'cards': 1,
#   'case': 5,
#   'cheaper': 1,
#   'check': 1,
#   'clean': 1,
#   'clear': 1,
#   'compact': 1,
#   'completely': 1,
#   'condition': 2,
#   'construction': 1,
#   'converter': 1,
#   'cool': 1,
#   'couple': 1,
#   'cover': 1,
#   'cross': 1,
#   'cute': 2,
#   'days': 1,
#   'decent': 1,
#   'demo': 1,
#   'details': 1,
#   'ding': 1,
#   'dispersion': 1,
#   'double': 1,
#   'eclipsed': 1,
#   'email': 1,
#   'etc': 1,
#   'even': 1,
#   'except': 1,
#   'exposure': 3,
#   'f28': 2,
#   'f63': 1,
#   'famous': 1,
#   'fancy': 1,
#   'feel': 1,
#   'film': 2,
#   'finallythe': 1,
#   'find': 1,
#   'fine': 1,
#   'fits': 1,
#   'flash': 2,
#   'flip': 1,
#   'focus': 2,
#   'folding': 1,
#   'free': 1,
#   'gems': 2,
#   'get': 2,
#   'good': 1,
#   'guess': 1,
#   'hard': 2,
#   'hassle': 1,
#   'head': 1,
#   'holding': 1,
#   'image': 1,
#   'interchangeable': 1,
#   "it'd": 1,
#   'kinda': 1,
#   'leather': 1,
#   'leatherette': 1,
#   'lens': 13,
#   'lenses': 5,
#   'lever': 1,
#   'lightmeter': 1,
#   'literature': 1,
#   'little': 3,
#   'longer': 1,
#   'made': 3,
#   'manual': 2,
#   'maxxum': 1,
#   'mean': 1,
#   'metal': 2,
#   'meters': 1,
#   'mind': 1,
#   'minolta': 2,
#   'mint': 2,
#   'miscellaneous': 1,
#   'mount': 1,
#   'mundane': 1,
#   'near': 1,
#   'nearly': 1,
#   'new': 1,
#   'nice': 2,
#   'nikon': 2,
#   'nonai': 1,
#   'nothin': 1,
#   'odd': 1,
#   'offer': 1,
#   'old': 1,
#   'older': 1,
#   'olympus': 2,
#   'om1': 1,
#   'onto': 1,
#   'optics': 1,
#   'pentax': 3,
#   'perfect': 1,
#   'peterman': 1,
#   'photo': 1,
#   'predecessor': 1,
#   'pretty': 1,
#   'priced': 1,
#   'rangefinder': 1,
#   'really': 1,
#   'release': 1,
#   'removable': 1,
#   'roamer': 1,
#   'screwmount': 1,
#   'self': 1,
#   'sell': 1,
#   'sensor': 1,
#   'set': 1,
#   'shape': 1,
#   'sharp': 1,
#   'shipping': 1,
#   'shoe': 1,
#   'shorter': 1,
#   'shutter': 1,
#   'since': 1,
#   'slr': 1,
#   'split': 1,
#   'strap': 2,
#   'stuff': 4,
#   'super': 2,
#   'supertakumar': 1,
#   'tang': 1,
#   "that'll": 1,
#   'think': 1,
#   'tilt': 1,
#   'time': 1,
#   'timer': 1,
#   'tiny': 1,
#   'tokina': 2,
#   'true': 1,
#   'try': 1,
#   'universal': 1,
#   'used': 1,
#   'uses': 1,
#   'variable': 1,
#   'viewing': 1,
#   'vivitar': 3,
#   'warranty': 1,
#   'well': 2,
#   'weston': 1,
#   'work': 2,
#   'works': 1,
#   'years': 1,
#   'zoom': 1,
#   'zuiko': 1},
#  26: {'atheists': 1,
#   'bill': 1,
#   'billion': 1,
#   'champaignurbana': 1,
#   'christians': 1,
#   'class': 1,
#   'clinton': 1,
#   'cobb': 1,
#   'cobbalexialisuiucedu': 1,
#   'creationism': 1,
#   'cuts': 1,
#   'debate': 2,
#   'debating': 1,
#   'deficits': 1,
#   'discussions': 1,
#   'dollar': 1,
#   'evolutionism': 1,
#   'illinois': 1,
#   'length': 1,
#   'mac': 1,
#   'michael': 1,
#   'middle': 1,
#   'new': 1,
#   'passion': 1,
#   'pay': 1,
#   'programs': 1,
#   'raise': 1,
#   'since': 1,
#   'spending': 1,
#   'still': 2,
#   'taxes': 2,
#   'time': 1,
#   'true': 1,
#   'unabated': 1,
#   'university': 1},
#  27: {'19apr199310484591utarlgutaedu': 1,
#   '250k': 1,
#   'according': 1,
#   'agents': 2,
#   'agree': 1,
#   'arlington': 1,
#   'article': 1,
#   'automatic': 1,
#   'b645zawutarlgutaedu': 1,
#   'barbedwire': 1,
#   'behind': 1,
#   'bill': 1,
#   'bit': 1,
#   'building': 1,
#   'burning': 2,
#   'captivity': 1,
#   'chemicalwarfare': 1,
#   'children': 1,
#   'clinton': 1,
#   'comes': 1,
#   'confirms': 1,
#   'considered': 1,
#   'continue': 1,
#   'continues': 1,
#   'davidians': 1,
#   'deceit': 1,
#   'diehard': 1,
#   'enough': 1,
#   'evidence': 1,
#   'executive': 1,
#   'faith': 1,
#   'fan': 1,
#   'fit': 1,
#   'follow': 1,
#   'goes': 1,
#   'government': 1,
#   'guess': 1,
#   'help': 1,
#   'highcaliber': 1,
#   'hoard': 1,
#   'hyatt': 1,
#   'innocents': 3,
#   'involved': 1,
#   'judgments': 1,
#   'juggernauts': 1,
#   'kill': 1,
#   'killed': 1,
#   'lawenforcement': 1,
#   'lead': 1,
#   'leadership': 1,
#   'leaving': 1,
#   'let': 1,
#   'likewise': 1,
#   'line': 1,
#   'logically': 1,
#   'loon': 1,
#   'messiahfollowing': 1,
#   'mount': 1,
#   'mpython': 1,
#   'much': 1,
#   'nice': 1,
#   'now': 1,
#   'office': 1,
#   'ones': 1,
#   'onewhorewards': 1,
#   'others': 1,
#   'parents': 1,
#   'patience': 1,
#   'people': 1,
#   'possibly': 1,
#   'pretty': 1,
#   'prevented': 1,
#   'quickly': 1,
#   'quite': 2,
#   'really': 1,
#   'religion': 1,
#   'repressed': 1,
#   'saints': 2,
#   'seems': 1,
#   'selfappointed': 1,
#   'shall': 1,
#   'sheesh': 1,
#   'started': 1,
#   'stepbystep': 1,
#   'stephen': 3,
#   'strands': 1,
#   'subject': 2,
#   'suffered': 1,
#   'thank': 1,
#   'threat': 1,
#   'thyatsdflonestarorg': 1,
#   'tom': 1,
#   'use': 1,
#   'used': 1,
#   'veiled': 1,
#   'weapons': 1,
#   'webs': 1,
#   'whether': 1,
#   'works': 1,
#   'worth': 1,
#   'writes': 1,
#   'yeah': 1},
#  28: {'able': 1,
#   'add': 1,
#   'aimed': 1,
#   'andor': 1,
#   'appreciated': 1,
#   'arcane': 1,
#   'attempting': 1,
#   'barbara': 1,
#   'basic': 1,
#   'blank': 3,
#   'bool': 2,
#   'california': 1,
#   'called': 3,
#   'cause': 1,
#   'center': 1,
#   'code': 3,
#   'composition': 1,
#   'computer': 1,
#   'copied': 2,
#   'current': 1,
#   'debugging': 1,
#   'design': 1,
#   'done': 1,
#   'dougfoxtrotccmrcucsbedu': 1,
#   'douglas': 1,
#   'else': 1,
#   'even': 1,
#   'existing': 1,
#   'find': 1,
#   'function': 4,
#   'get': 1,
#   'hacking': 1,
#   'internet': 1,
#   'keys': 1,
#   'likely': 1,
#   'means': 1,
#   'missing': 1,
#   'mouse': 1,
#   'moved': 1,
#   'music': 1,
#   'myeventhandle': 2,
#   'never': 1,
#   'new': 1,
#   'nextmail': 1,
#   'nextsavescreenbrightness': 2,
#   'nextsavescreenscron': 1,
#   'nextsetlasteventtime': 1,
#   'nxscreenbrightnessmyeventhandle': 1,
#   'nxsetscreenbrightness': 2,
#   'omron': 1,
#   'on0': 1,
#   'on1': 1,
#   'problem': 2,
#   'properly': 1,
#   'question': 2,
#   'reason': 1,
#   'research': 1,
#   'return': 1,
#   'right': 1,
#   'santa': 1,
#   'save': 1,
#   'saver': 1,
#   'savescreen': 2,
#   'scott': 1,
#   'scr': 1,
#   'screen': 5,
#   'screenptr': 1,
#   'screensaver': 1,
#   'screensaveron': 2,
#   'see': 2,
#   'server': 4,
#   'serveros': 1,
#   'setting': 1,
#   'static': 1,
#   'thanks': 1,
#   'tipshelp': 1,
#   'true': 1,
#   'turn': 1,
#   'typed': 1,
#   'unblank': 1,
#   'unblanks': 1,
#   'university': 1,
#   "user's": 1,
#   'versions': 1,
#   'wakes': 1,
#   'way': 1,
#   'working': 1},
#  29: {'1800getnine': 1,
#   '5fg': 1,
#   '6fg': 1,
#   'accelerator': 1,
#   'bnc': 3,
#   'bought': 1,
#   'cable': 1,
#   'card': 2,
#   'cards': 2,
#   'connector': 1,
#   'connectors': 1,
#   'contacting': 1,
#   'dept': 1,
#   'display': 1,
#   'dsub': 1,
#   'email': 1,
#   'extron': 1,
#   'get': 1,
#   'good': 2,
#   'hello': 1,
#   'highest': 1,
#   'home': 1,
#   'information': 1,
#   'just': 1,
#   'know': 2,
#   'level': 1,
#   'like': 2,
#   'mark': 1,
#   'marlow': 1,
#   'marlowworldstdcom': 1,
#   'math': 1,
#   'mike': 2,
#   'mikeukprukyedu': 1,
#   'mills': 2,
#   'nec': 1,
#   'opposed': 1,
#   'optimize': 1,
#   'order': 1,
#   'outputs': 1,
#   'possible': 1,
#   'quality': 1,
#   'rates': 1,
#   'recently': 1,
#   'refresh': 1,
#   'rutgers': 1,
#   'sammsukyedu': 2,
#   'sciences': 1,
#   'sells': 1,
#   'set': 1,
#   'thanks': 1,
#   'try': 1,
#   'trying': 1,
#   'type': 1,
#   'use': 1,
#   'usual': 1,
#   'uunetukmasam': 1,
#   'vga': 2,
#   'video': 1,
#   'work': 1,
#   'works': 1,
#   'writes': 1},
#  30: {'1993apr2215352810877raroyalroadsca': 1,
#   'able': 1,
#   'activities': 1,
#   'actually': 1,
#   'aith': 1,
#   'alink': 1,
#   'also': 1,
#   'anyone': 1,
#   'article': 1,
#   'ask': 1,
#   'blame': 1,
#   'bottom': 1,
#   'check': 1,
#   'cheers': 1,
#   'choice': 2,
#   'choose': 2,
#   'chosen': 1,
#   'christ': 1,
#   'clearly': 2,
#   'cliff': 3,
#   'consequence': 1,
#   'damnation': 1,
#   'decide': 2,
#   'die': 1,
#   'direction': 2,
#   'edge': 1,
#   'else': 1,
#   'equal': 1,
#   'established': 1,
#   'eternal': 1,
#   'everyone': 1,
#   'example': 1,
#   'existentialism': 1,
#   'fact': 1,
#   'god': 3,
#   'going': 1,
#   'hardly': 1,
#   'interested': 1,
#   'jesus': 1,
#   'jump': 6,
#   'just': 1,
#   'kent': 1,
#   'kierkegaard': 1,
#   'knows': 1,
#   'ksand': 1,
#   'leap': 2,
#   'lee': 1,
#   'lies': 1,
#   'like': 1,
#   'listen': 1,
#   'makes': 1,
#   'making': 1,
#   'malcolm': 1,
#   'mentioned': 1,
#   'might': 1,
#   'mleepostroyalroadsca': 1,
#   'moment': 1,
#   'net': 1,
#   'notion': 1,
#   'now': 1,
#   'owe': 1,
#   'plunge': 2,
#   'point': 1,
#   'points': 1,
#   'possible': 1,
#   'prevent': 1,
#   'private': 1,
#   'prove': 1,
#   'rejecting': 1,
#   'rise': 1,
#   'sandviknewtonapplecom': 1,
#   'seeing': 1,
#   'seen': 1,
#   'sent': 1,
#   'shows': 1,
#   'solution': 1,
#   'son': 1,
#   'splat': 3,
#   'stand': 1,
#   'stop': 1,
#   'system': 1,
#   'taking': 1,
#   'tell': 2,
#   'time': 1,
#   'took': 1,
#   'transcendental': 2,
#   'trying': 1,
#   'understand': 1,
#   'values': 1,
#   'words': 1,
#   'wrote': 1},
#  31: {'abdeen': 1,
#   'according': 1,
#   'agency': 1,
#   'american': 1,
#   'arab': 3,
#   'arabs': 1,
#   'basis': 1,
#   'bibliography': 1,
#   'books': 2,
#   'center': 1,
#   'challenge': 1,
#   'commitments': 1,
#   'consequences': 1,
#   'cprigcapcorg': 1,
#   'croom': 1,
#   "davidsson's": 1,
#   'davis': 1,
#   'difference': 2,
#   'discrimination': 1,
#   'duke': 1,
#   'durham': 1,
#   'eaford': 1,
#   'east': 2,
#   'elimination': 1,
#   'english': 1,
#   'external': 1,
#   'forms': 1,
#   'halevi': 1,
#   'helm': 1,
#   'ilan': 1,
#   'imperialism': 1,
#   'institutionalized': 1,
#   'internal': 1,
#   'international': 3,
#   'intervention': 1,
#   'israel': 4,
#   'israelus': 1,
#   'jabara': 1,
#   'jewish': 1,
#   'jiryis': 1,
#   'john': 1,
#   'judaism': 2,
#   'justice': 1,
#   'kayyali': 1,
#   'kind': 1,
#   'law': 1,
#   'london': 3,
#   'ltd': 2,
#   'mallison': 2,
#   'middle': 2,
#   'monthly': 1,
#   'nationality': 1,
#   'necessity': 1,
#   'needs': 1,
#   'new': 1,
#   'objective': 1,
#   'opposition': 1,
#   'organisation': 1,
#   'organizationjewish': 1,
#   'p2741': 1,
#   'p310': 1,
#   'palestine': 1,
#   'policy': 1,
#   'press': 2,
#   'quarterly': 2,
#   'quigley': 1,
#   'racial': 1,
#   'racism': 2,
#   'research': 1,
#   'responsibility': 1,
#   'review': 1,
#   'roselle': 1,
#   'sabri': 1,
#   'sally': 1,
#   'scan': 1,
#   'scholars': 1,
#   'see': 1,
#   'society': 1,
#   'sources': 1,
#   'springsummer': 2,
#   'state': 1,
#   'status': 1,
#   'studies': 2,
#   'tekiner': 1,
#   'think': 1,
#   'today': 1,
#   'university': 1,
#   'uri': 1,
#   'uses': 1,
#   'washington': 1,
#   'writes': 1,
#   'writings': 1,
#   'york': 1,
#   'zed': 2,
#   'zionism': 4,
#   'zionist': 2},
#  32: {'arianism': 1,
#   'attempt': 3,
#   'avoid': 1,
#   'aware': 1,
#   'brothers': 1,
#   'certainly': 1,
#   'christian': 4,
#   'christianity': 2,
#   'churches': 1,
#   'claim': 1,
#   'claiming': 1,
#   'closed': 1,
#   'core': 1,
#   'different': 1,
#   'distinguish': 1,
#   'else': 1,
#   'espouse': 1,
#   'everyone': 1,
#   'fact': 1,
#   'fall': 1,
#   'flavours': 1,
#   'god': 2,
#   'going': 1,
#   'group': 1,
#   'identify': 1,
#   'instead': 1,
#   'isis': 1,
#   'issues': 2,
#   'jon': 1,
#   'jws': 1,
#   'known': 1,
#   'livesey': 1,
#   'loudly': 2,
#   'majority': 1,
#   'mangoecsumdedu': 1,
#   "marv'lous": 1,
#   'nicene': 2,
#   'obvious': 1,
#   'otherwise': 1,
#   'ownership': 1,
#   'peace': 3,
#   'phrase': 2,
#   'position': 1,
#   'pray': 1,
#   'rejected': 1,
#   'roughly': 1,
#   'similar': 1,
#   'sod': 1,
#   'strife': 1,
#   'theological': 1,
#   'thing': 1,
#   'tovemangoe': 1,
#   'tried': 2,
#   'true': 2,
#   'using': 1,
#   'vast': 1,
#   'viewpoints': 1,
#   'virtually': 1,
#   'well': 2,
#   'wingate': 1,
#   'within': 1,
#   'writes': 1,
#   'yet': 1},
#  33: {'centre': 1,
#   'cruel': 5,
#   'cruell': 1,
#   'death': 1,
#   'definition': 2,
#   'definitions': 1,
#   'eyes': 2,
#   'fig': 1,
#   'figuratively': 1,
#   'first': 1,
#   'frowning': 1,
#   'imagine': 1,
#   'imply': 1,
#   'inanimate': 1,
#   'incapable': 1,
#   'include': 1,
#   'keith': 1,
#   'man': 1,
#   'merciless': 1,
#   'mercy': 1,
#   'michael': 1,
#   'missed': 1,
#   'mmwangadobecom': 1,
#   'must': 1,
#   'nailes': 1,
#   'nails': 2,
#   'note': 1,
#   'object': 1,
#   'oed': 1,
#   'old': 1,
#   'painful': 1,
#   'painless': 1,
#   'parens': 1,
#   'plucke': 1,
#   'poore': 1,
#   'puniness': 1,
#   'punishment': 2,
#   'read': 1,
#   'reading': 1,
#   'samples': 1,
#   'say': 1,
#   'see': 1,
#   'sense': 1,
#   'show': 1,
#   'showing': 1,
#   'sorry': 1,
#   'stuff': 1,
#   'supposed': 1,
#   'sure': 1,
#   'text': 1,
#   'things': 1,
#   'thy': 1,
#   'transf': 1,
#   'transferred': 1,
#   'trying': 1,
#   'typed': 1,
#   'universe': 1,
#   'upon': 1,
#   'wang': 1,
#   'well': 1,
#   'writes': 1},
#  34: {'actually': 1,
#   "ain't": 1,
#   'also': 1,
#   'ariane': 1,
#   'article': 1,
#   'attempt': 1,
#   'basically': 1,
#   'big': 1,
#   'bit': 1,
#   'bought': 1,
#   'brothers': 1,
#   'business': 1,
#   'c5133agzxnewscsouiucedu': 1,
#   'case': 1,
#   'cheap': 1,
#   'cheapest': 1,
#   'come': 1,
#   'commercial': 2,
#   'commercially': 1,
#   'complicates': 1,
#   'expendable': 1,
#   'facilities': 1,
#   'get': 1,
#   'governemnt': 1,
#   'government': 1,
#   'granted': 1,
#   'happy': 1,
#   'heavy': 1,
#   'henry': 1,
#   'henryzootorontoedu': 1,
#   'hopkins': 1,
#   'iii': 2,
#   'intelsat': 1,
#   'ironic': 1,
#   "iv's": 1,
#   'jbh55289uxacsouiucedu': 1,
#   'josh': 1,
#   'just': 2,
#   'kipling': 1,
#   'launch': 2,
#   'launchers': 1,
#   'launches': 4,
#   'learn': 1,
#   'least': 1,
#   'little': 1,
#   'made': 1,
#   "man's": 1,
#   'market': 2,
#   'marketing': 1,
#   'mars': 2,
#   'memory': 1,
#   'multisatellite': 1,
#   'need': 1,
#   'observer': 2,
#   'orbit': 1,
#   'order': 1,
#   'pad': 1,
#   'poorly': 1,
#   'pound': 1,
#   'prevented': 1,
#   'problem': 2,
#   'problems': 1,
#   'properly': 2,
#   'put': 1,
#   'quite': 1,
#   'rather': 1,
#   'reached': 1,
#   'refurbishment': 1,
#   'secondary': 1,
#   'sell': 1,
#   'serves': 1,
#   'significantly': 1,
#   'single': 1,
#   'space': 1,
#   'spencer': 1,
#   'started': 1,
#   'stranded': 1,
#   'task': 1,
#   'time': 1,
#   'titan': 5,
#   'toronto': 1,
#   'used': 1,
#   'utzoohenry': 1,
#   'want': 1,
#   'way': 1,
#   'work': 3,
#   'writes': 1,
#   'wrong': 1,
#   'year': 1,
#   'zoology': 1},
#  35: {'17lb': 1,
#   '1993apr217015724251ke4zvuucp': 1,
#   'aforesaid': 1,
#   'also': 1,
#   'apparent': 1,
#   'around': 1,
#   'article': 2,
#   'barrels': 1,
#   'basically': 1,
#   'body': 1,
#   'c512wcb0m1cscmuedu': 1,
#   'centigrade': 1,
#   'chains': 1,
#   'coffman': 1,
#   'coldest': 1,
#   'complexity': 1,
#   'constants': 1,
#   'course': 1,
#   'cubic': 1,
#   'days': 1,
#   'deleted': 1,
#   'density': 1,
#   'difference': 1,
#   'divided': 1,
#   'doug': 1,
#   'due': 1,
#   'easy': 1,
#   'else': 1,
#   'employer': 1,
#   'even': 1,
#   'everyone': 1,
#   'exactly': 1,
#   'express': 1,
#   'expressed': 1,
#   'face': 1,
#   'fact': 1,
#   'fahrenheit': 1,
#   'feet': 1,
#   'figure': 1,
#   'foo': 1,
#   'foot': 1,
#   'force': 1,
#   'fot': 1,
#   'ftsec2': 2,
#   'fundamental': 1,
#   'fwiw': 1,
#   'gary': 2,
#   'garyke4zvuucp': 1,
#   'going': 1,
#   'gravity': 1,
#   'haines': 1,
#   'hanging': 1,
#   'history': 1,
#   'hours': 1,
#   'hundredths': 1,
#   'imperial': 2,
#   'inches': 1,
#   'insec2': 1,
#   'keep': 1,
#   'like': 4,
#   'marked': 1,
#   'marks': 1,
#   'matter': 1,
#   'maybe': 2,
#   'mean': 1,
#   'metric': 1,
#   'mine': 1,
#   'minutes': 1,
#   'months': 1,
#   'moon': 1,
#   'multiple': 1,
#   'multiplicity': 1,
#   'names': 1,
#   'natural': 1,
#   'necessarily': 1,
#   'need': 1,
#   'nick': 1,
#   'nickhcscmuedu': 1,
#   'omnipresent': 1,
#   'opinions': 1,
#   'order': 1,
#   'page': 1,
#   'particular': 1,
#   'per': 1,
#   'person': 1,
#   'point': 1,
#   'prefixes': 1,
#   'quantities': 1,
#   'quantity': 1,
#   'quart': 1,
#   'relating': 1,
#   'remaining': 1,
#   'remember': 1,
#   'represent': 1,
#   'revisionists': 1,
#   'right': 1,
#   'russian': 1,
#   'sane': 1,
#   'saying': 1,
#   'scale': 2,
#   'seconds': 1,
#   'sick': 1,
#   'something': 1,
#   'space': 1,
#   'stuff': 1,
#   'system': 3,
#   'tell': 1,
#   'temperature': 2,
#   'thermometer': 2,
#   'thing': 1,
#   'turns': 1,
#   'type': 2,
#   'unit': 2,
#   'units': 1,
#   'use': 2,
#   'useful': 1,
#   'uses': 1,
#   'values': 1,
#   'volunteer': 1,
#   'want': 1,
#   'way': 1,
#   'weight': 2,
#   'win': 1,
#   'winter': 1,
#   'writes': 2,
#   'written': 1,
#   'yards': 1,
#   'years': 1},
#  36: {'also': 1,
#   'avaliable': 1,
#   'cant': 1,
#   'card': 1,
#   'commonly': 1,
#   'companies': 1,
#   'get': 1,
#   'infrared': 1,
#   'maybe': 1,
#   'much': 1,
#   'part': 1,
#   'radio': 1,
#   'really': 1,
#   'seas': 1,
#   'sells': 1,
#   'sensor': 1,
#   'shack': 1,
#   'states': 1,
#   'write': 1},
#  37: {'1993apr1616542327204linusmitreorg': 1,
#   '1993apr171226511874sugrauucp': 1,
#   'anyone': 1,
#   'applies': 1,
#   'article': 2,
#   'bandwidth': 1,
#   'better': 1,
#   'bunch': 2,
#   'case': 1,
#   'cases': 1,
#   'chicago': 1,
#   'civil': 1,
#   'confess': 1,
#   'confused': 1,
#   'contains': 1,
#   'copyright': 3,
#   'copyrighted': 1,
#   'criminal': 2,
#   'deliberately': 1,
#   'distribution': 1,
#   'encoded': 1,
#   'evading': 1,
#   'file': 1,
#   'get': 1,
#   'gifs': 1,
#   'girl': 1,
#   'grant': 1,
#   'hanging': 1,
#   'illegal': 1,
#   'immunity': 1,
#   'infringements': 1,
#   'instead': 1,
#   'jake': 1,
#   'judge': 1,
#   'just': 2,
#   'keep': 1,
#   'kenneth': 1,
#   'kensugrauucp': 1,
#   'key': 1,
#   'keyphrase': 2,
#   'kiddie': 1,
#   'kiss': 1,
#   'kramarsky': 1,
#   'law': 1,
#   'learned': 1,
#   'make': 1,
#   'may': 1,
#   'murder': 1,
#   'night': 1,
#   'peanuts': 2,
#   'peter': 1,
#   'porn': 1,
#   'posession': 1,
#   'ptreibistromathmitreorg': 1,
#   'quibble': 1,
#   'scans': 1,
#   'school': 1,
#   'smk5quadsuchicagoedu': 1,
#   'sorry': 1,
#   'steve': 2,
#   'stevefaeriechiilus': 1,
#   'straight': 1,
#   'strips': 2,
#   'test': 1,
#   'things': 1,
#   'think': 1,
#   'trei': 1,
#   'university': 1,
#   'use': 1,
#   'violation': 1,
#   'want': 1,
#   'waste': 1,
#   'whatever': 1,
#   'writes': 2},
#  38: {'125kb': 1,
#   'access': 1,
#   'accessed': 1,
#   'anyone': 1,
#   'assists': 1,
#   'based': 1,
#   'budget': 1,
#   'buy': 1,
#   'carsonasfuca': 1,
#   'check': 1,
#   'compressed': 1,
#   'compuserve': 2,
#   'cost': 1,
#   'dale': 1,
#   'decision': 1,
#   'download': 1,
#   'features': 1,
#   'help': 2,
#   'higher': 1,
#   'hypercard': 1,
#   'know': 1,
#   'later': 1,
#   'let': 1,
#   'longer': 1,
#   'mac': 2,
#   'main': 1,
#   'making': 1,
#   'modem': 1,
#   'much': 1,
#   'please': 1,
#   'software': 1,
#   'speed': 1,
#   'stack': 2,
#   'thanks': 1,
#   'used': 2,
#   'version': 1,
#   'ziffnetmac': 1},
# ...
#   'saudi': 1,
#   'seem': 1,
#   'situations': 1,
#   'speak': 1,
#   'standard': 1,
#   'sudan': 1,
#   'suffer': 1,
#   'teachings': 1,
#   'themsselves': 1,
#   'tourists': 1,
#   'true': 1,
#   'usually': 1,
#   'war': 1,
#   'writes': 1,
#   'years': 1,
#   'yet': 1,
#   'york': 1},
#  988: {'1993apr2112453113053acdalca': 1,
#   'alex': 1,
#   'along': 1,
#   'article': 1,
#   'better': 1,
#   'compatability': 1,
#   'damn': 1,
#   'drives': 1,
#   'faster': 2,
#   'fire': 1,
#   'frying': 1,
#   'gateway': 1,
#   'getting': 1,
#   'going': 1,
#   'ibm': 1,
#   'ide': 1,
#   'jheregiastateedu': 1,
#   'lot': 1,
#   'mac': 1,
#   'new': 1,
#   'noises': 1,
#   'pan': 1,
#   'pretty': 1,
#   'question': 1,
#   'retching': 1,
#   'scsi': 2,
#   'selling': 1,
#   'sig': 1,
#   'stupid': 1,
#   'sure': 1,
#   'talk': 1,
#   'tominatracdalca': 1,
#   'universe': 1,
#   'user': 1,
#   'writes': 1},
#  989: {'also': 1,
#   'america': 2,
#   'andrew': 1,
#   'article': 2,
#   'babe': 1,
#   'baseball': 3,
#   'biancalana': 1,
#   'big': 1,
#   'bighelmet': 1,
#   'brodcaster': 1,
#   'brought': 1,
#   'buddy': 1,
#   'c5k7nk7tvnewscsouiucedu': 1,
#   'called': 1,
#   'check': 1,
#   'colorado': 1,
#   'column': 3,
#   'combined': 1,
#   'contest': 1,
#   'csc2imdcabellvcuedu': 1,
#   'day': 2,
#   'derby': 1,
#   'don': 1,
#   'dream': 1,
#   'every': 3,
#   'fan': 1,
#   'get': 1,
#   'guy': 2,
#   'happen': 1,
#   'henley': 1,
#   'highlights': 1,
#   'hit': 1,
#   'home': 1,
#   'howabout': 1,
#   'ian': 1,
#   'idiot': 2,
#   'inquirer': 1,
#   'jayson': 1,
#   'kiner': 1,
#   'kinerisms': 1,
#   'koffler': 1,
#   'last': 1,
#   'laugh': 1,
#   'lgtgah': 1,
#   'lines': 1,
#   'live': 1,
#   'make': 1,
#   'mets': 1,
#   'might': 1,
#   'month': 1,
#   'nolan': 1,
#   'occured': 1,
#   'omar': 1,
#   'philadelphia': 1,
#   'piece': 1,
#   'radio': 1,
#   'ralph': 1,
#   'really': 1,
#   'review': 2,
#   'rkofflerux4csouiucedu': 2,
#   'rob': 1,
#   'rockies': 1,
#   'runs': 1,
#   'ruth': 1,
#   'ryan': 1,
#   'section': 1,
#   'since': 1,
#   'situations': 1,
#   'someone': 1,
#   'sometime': 1,
#   'sort': 1,
#   'sports': 1,
#   'sportswriting': 1,
#   'stands': 1,
#   'stark': 2,
#   'stats': 1,
#   'stupid': 1,
#   'thought': 1,
#   'thunk': 1,
#   'time': 1,
#   'tomorrow': 1,
#   'tuesday': 1,
#   'twice': 1,
#   'unusual': 2,
#   'vizquel': 1,
#   'week': 4,
#   'woulda': 1,
#   'writer': 1,
#   'writes': 7,
#   'year': 1},
#  990: {'1qgi8einnhs5skeenaucsubcca': 1,
#   'advance': 1,
#   'anyone': 1,
#   'article': 2,
#   'big': 1,
#   'bit': 1,
#   'bolt': 1,
#   'buy': 2,
#   'c5lmtrmo7mentorccpurdueedu': 1,
#   'car': 1,
#   'change': 2,
#   'chong': 1,
#   'claw': 1,
#   'clockwise': 1,
#   'coil': 1,
#   'compartment': 1,
#   'counter': 1,
#   'damn': 1,
#   'drill': 1,
#   'electric': 1,
#   'engine': 1,
#   'failed': 1,
#   'gems': 1,
#   'gets': 1,
#   'good': 1,
#   'hammer': 1,
#   'heli': 2,
#   'hello': 1,
#   'hole': 2,
#   'invented': 1,
#   'kind': 1,
#   'know': 1,
#   'lam': 1,
#   'larger': 1,
#   'leak': 1,
#   'leaks': 1,
#   'little': 1,
#   'lubricants': 1,
#   'marshattfeserveccpurdueedu': 1,
#   'much': 1,
#   'notice': 1,
#   'now': 1,
#   'oil': 3,
#   'oils': 1,
#   'pours': 1,
#   'pry': 1,
#   'rethread': 1,
#   'retighten': 1,
#   'safe': 1,
#   'still': 1,
#   'straight': 1,
#   'succeed': 1,
#   'suitable': 1,
#   'take': 2,
#   'thank': 1,
#   'thats': 1,
#   'theads': 1,
#   'thing': 1,
#   'think': 1,
#   'tight': 1,
#   'time': 2,
#   'trade': 1,
#   'tried': 1,
#   'turn': 3,
#   'uberer': 1,
#   'use': 1,
#   'used': 1,
#   'way': 1,
#   'wd40etc': 1,
#   'winson': 1,
#   'without': 1,
#   'worry': 2,
#   'writes': 2,
#   'yes': 1,
#   'yik': 1,
#   'yiklamunixgubcca': 1},
#  991: {'43011higgins': 1,
#   '49th': 1,
#   'accelerator': 1,
#   'advantage': 1,
#   'article': 3,
#   'association': 1,
#   'bill': 1,
#   'bitnet': 1,
#   'briefly': 1,
#   'c5r2dk764skatesgsfcnasagov': 1,
#   'charles': 1,
#   'chuck': 1,
#   'commercial': 1,
#   'competitive': 1,
#   'current': 2,
#   'department': 1,
#   'disclaimer': 1,
#   'divine': 2,
#   'energy': 1,
#   'federal': 1,
#   'fermi': 1,
#   'fermilab': 1,
#   'fiction': 1,
#   'funding': 1,
#   'gaining': 1,
#   'gulp': 1,
#   'higgins': 1,
#   'higginsfnalbitnet': 1,
#   'higginsfnalfnalgov': 1,
#   'internet': 1,
#   'just': 1,
#   'laboratory': 1,
#   'like': 1,
#   'military': 1,
#   'mine': 1,
#   'much': 1,
#   'national': 1,
#   'news': 1,
#   'opinion': 1,
#   'organization': 1,
#   'pointer': 1,
#   'regular': 1,
#   'represent': 1,
#   'research': 1,
#   'science': 2,
#   'shifted': 1,
#   'spanhepnet': 1,
#   'things': 1,
#   'universities': 1,
#   'utility': 1,
#   'views': 1,
#   'ward': 1,
#   'work': 1,
#   'writes': 1,
#   'xrcjdresolvegsfcnasagov': 1,
#   'zap': 1},
#  992: {'1993apr12148565339rapnetsanderslockheedcom': 1,
#   '19yearold': 1,
#   '1pkl2nkkagenesismcscom': 1,
#   'acts': 1,
#   'age': 1,
#   'agency': 1,
#   'among': 1,
#   'annals': 1,
#   'another': 1,
#   'antisemites': 1,
#   'antisemitic': 1,
#   'anything': 1,
#   'apply': 1,
#   'arfgenesismcscom': 2,
#   'army': 1,
#   'article': 2,
#   'attack': 1,
#   'attacked': 1,
#   'attacker': 3,
#   'attempts': 1,
#   'away': 1,
#   'babb': 1,
#   'babbk2': 1,
#   'back': 1,
#   'bigotry': 1,
#   'bill': 2,
#   'blank': 1,
#   'bound': 1,
#   'circumstances': 1,
#   'civil': 1,
#   'clear': 2,
#   'color': 1,
#   'comes': 1,
#   'concerned': 1,
#   'considers': 1,
#   'crippled': 1,
#   'crystal': 1,
#   'culpable': 1,
#   'damnation': 1,
#   'deeds': 1,
#   'deter': 1,
#   'different': 1,
#   'discuss': 1,
#   'duty': 1,
#   'employer': 1,
#   'ensure': 1,
#   'ethnic': 1,
#   'even': 1,
#   'event': 1,
#   'evil': 1,
#   'example': 1,
#   'exist': 1,
#   'fear': 1,
#   'fine': 1,
#   'fire': 1,
#   'fired': 1,
#   'firing': 1,
#   'fit': 1,
#   'followup': 1,
#   'foremost': 1,
#   'friend': 1,
#   'gaged': 1,
#   'gazan': 1,
#   'gender': 1,
#   'government': 1,
#   'group': 2,
#   'head': 2,
#   'help': 1,
#   "historian's": 1,
#   'hit': 1,
#   'human': 1,
#   'identified': 1,
#   'iii': 1,
#   'indication': 1,
#   'injure': 1,
#   'injured': 1,
#   'instead': 1,
#   'irrespective': 1,
#   'israel': 1,
#   'israeli': 1,
#   'jack': 3,
#   "jack's": 1,
#   'jail': 1,
#   'jewish': 3,
#   'kill': 1,
#   'killed': 2,
#   'laws': 1,
#   'lesson': 1,
#   'life': 1,
#   'lightly': 1,
#   'lives': 1,
#   'man': 2,
#   "man's": 1,
#   'mention': 1,
#   'merely': 1,
#   'might': 1,
#   'naked': 1,
#   'neck': 1,
#   'nonjews': 1,
#   'ones': 1,
#   'opened': 1,
#   'opinion': 1,
#   'opinions': 1,
#   'orientation': 1,
#   'particularly': 2,
#   'people': 4,
#   'please': 1,
#   'point': 1,
#   'poster': 1,
#   "posterity's": 1,
#   'praiseworthy': 1,
#   'problem': 2,
#   'proposals': 1,
#   'pushed': 1,
#   'rabid': 1,
#   'rather': 1,
#   'rationally': 1,
#   'really': 1,
#   'religion': 1,
#   'remembered': 1,
#   'repeatedly': 1,
#   'represent': 1,
#   'reprimand': 1,
#   'respect': 1,
#   'responsible': 1,
#   'riggs': 1,
#   'said': 1,
#   'scandalous': 1,
#   'schmidling': 3,
#   'scott': 1,
#   'see': 1,
#   'seems': 1,
#   'seen': 1,
#   'senate': 1,
#   'severe': 1,
#   'sexual': 1,
#   'shot': 1,
#   'sick': 1,
#   'sig': 1,
#   'similar': 1,
#   'skin': 1,
#   'soldier': 3,
#   'soldiers': 5,
#   'specific': 1,
#   'stabbed': 2,
#   'standing': 1,
#   'statements': 1,
#   'supporters': 1,
#   'suspect': 1,
#   'tacitus': 1,
#   'talking': 1,
#   'terms': 1,
#   'virtue': 1,
#   'visitors': 1,
#   'walking': 1,
#   'whole': 1,
#   'witnesses': 1,
#   'words': 1,
#   'wounds': 1,
#   'writes': 2,
#   'wrong': 1,
#   'wrote': 1},
#  993: {'34f': 1,
#   'actually': 1,
#   'anyone': 2,
#   'bob': 1,
#   'bucks': 1,
#   'bus': 2,
#   'cards': 1,
#   'controller': 2,
#   'controllers': 1,
#   'effect': 1,
#   'get': 2,
#   'heard': 2,
#   'interested': 1,
#   'kimball': 1,
#   'knows': 1,
#   'like': 2,
#   'local': 1,
#   'mastering': 1,
#   'new': 1,
#   'problem': 2,
#   'problems': 1,
#   'put': 1,
#   'rkimballqualcommcom': 1,
#   'scoop': 1,
#   'scsi': 2,
#   'shell': 1,
#   'slow': 1,
#   'someone': 1,
#   'something': 1,
#   'specifically': 1,
#   'straight': 1,
#   'system': 1,
#   'thing': 1,
#   'together': 1,
#   'trying': 1,
#   'ultrastor': 1,
#   'vesa': 1,
#   'video': 1,
#   'vlb': 3},
#  994: {'93108025818u28037uicvmuicedu': 1,
#   'able': 1,
#   'action': 1,
#   'anymore': 1,
#   'anyway': 1,
#   'article': 2,
#   'asking': 1,
#   'assuming': 1,
#   'away': 3,
#   'beginning': 1,
#   'books': 1,
#   'brass': 2,
#   'carrying': 1,
#   'catch': 1,
#   'caught': 1,
#   'chance': 1,
#   'collect': 1,
#   'collected': 1,
#   'concealed': 1,
#   'cont': 1,
#   'continue': 1,
#   'cops': 1,
#   'course': 1,
#   'curious': 1,
#   'data': 1,
#   'david': 2,
#   'day': 1,
#   'deal': 1,
#   'decided': 1,
#   'div': 1,
#   'education': 1,
#   'either': 1,
#   'elevator': 1,
#   'end': 1,
#   'essentially': 1,
#   'even': 1,
#   'evidence': 1,
#   'exactly': 1,
#   'fade': 2,
#   'find': 1,
#   'first': 1,
#   'folks': 1,
#   'friend': 1,
#   'get': 3,
#   'give': 1,
#   'great': 1,
#   'group': 1,
#   'guess': 1,
#   'gun': 2,
#   'happen': 2,
#   'hassle': 1,
#   'hear': 1,
#   'heard': 2,
#   'illinois': 1,
#   'info': 1,
#   'jason': 2,
#   'just': 3,
#   'justified': 1,
#   'killing': 1,
#   'kind': 2,
#   'kratz': 1,
#   'laughed': 1,
#   'laws': 1,
#   'library': 1,
#   'like': 2,
#   'likely': 2,
#   'look': 1,
#   'love': 1,
#   'many': 1,
#   'mine': 1,
#   'misdemeanor': 1,
#   'much': 1,
#   'net': 1,
#   'nobody': 1,
#   'note': 1,
#   'offense': 1,
#   'officer': 1,
#   'opinions': 1,
#   'pa146008utkvm1utkedu': 1,
#   'people': 2,
#   'perfectly': 1,
#   'point': 1,
#   'police': 1,
#   'pretty': 1,
#   'provided': 1,
#   'pull': 1,
#   'pushed': 1,
#   'question': 1,
#   'read': 1,
#   'recommends': 1,
#   'record': 1,
#   'regarding': 1,
#   'remember': 1,
#   'revolver': 1,
#   'saw': 2,
#   'say': 1,
#   'says': 1,
#   'seen': 1,
#   'semiauto': 1,
#   'services': 1,
#   'shaft': 1,
#   'shooting': 1,
#   'side': 1,
#   'situation': 2,
#   'somebody': 1,
#   'someone': 1,
#   'state': 1,
#   'statutes': 1,
#   'stay': 1,
#   'stayed': 1,
#   'still': 1,
#   'stuff': 1,
#   'subject': 1,
#   'take': 1,
#   'tenn': 1,
#   'tennessee': 1,
#   'thing': 1,
#   'things': 1,
#   'think': 2,
#   'time': 1,
#   'took': 1,
#   'trip': 1,
#   'trying': 1,
#   'type': 1,
#   'u28037uicvmccuicedu': 1,
#   'u28037uicvmuicedu': 1,
#   'univ': 1,
#   'using': 1,
#   'veal': 2,
#   'veal744735151266utkvm1utkedu': 1,
#   'vealutkvm1utkedu': 1,
#   'wait': 1,
#   'waited': 1,
#   'way': 1,
#   'weird': 1},
#  995: {'32bit': 3,
#   'anyway': 1,
#   'apple': 1,
#   'aware': 1,
#   'bill': 1,
#   'boards': 1,
#   'c5sku0l4lnewsudeledu': 1,
#   'case': 1,
#   'clean': 1,
#   'cleanliness': 1,
#   'enabler': 1,
#   'features': 1,
#   'fine': 1,
#   'getting': 1,
#   'iici': 1,
#   'iix': 2,
#   'johnston': 1,
#   'johnstonmeudeledu': 1,
#   'just': 1,
#   'justify': 1,
#   'market': 1,
#   'might': 1,
#   'mode32': 2,
#   'mother': 1,
#   'particular': 1,
#   'probably': 1,
#   'problems': 1,
#   'provide': 1,
#   'reason': 2,
#   'rom': 4,
#   'romswapping': 1,
#   'see': 1,
#   'sell': 1,
#   'sells': 1,
#   'shreve': 1,
#   'still': 1,
#   'technical': 1,
#   'trouble': 1,
#   'upgrading': 1,
#   'used': 1,
#   'well': 1,
#   'works': 2,
#   'writes': 1},
#  996: {'00cjmelchingleobsuvcbsuedu': 1,
#   '1993apr2123380318471bsuucs': 1,
#   'able': 1,
#   'aclu': 1,
#   'already': 1,
#   'also': 1,
#   'article': 1,
#   'back': 1,
#   'bmw': 1,
#   'bmwmoa': 1,
#   'bought': 1,
#   'breakin': 1,
#   'called': 1,
#   'comfortably': 1,
#   'cycle': 1,
#   'david': 1,
#   'day': 1,
#   'different': 1,
#   'dod': 1,
#   'easily': 1,
#   'enjoy': 1,
#   'even': 2,
#   'find': 1,
#   'first': 1,
#   'full': 1,
#   'gear': 1,
#   'get': 2,
#   'going': 1,
#   'highways': 1,
#   'hold': 1,
#   'hurt': 1,
#   'karr': 1,
#   'karrcscornelledu': 1,
#   'know': 2,
#   'least': 1,
#   'limit': 3,
#   'might': 2,
#   'miles': 3,
#   'mph': 3,
#   'need': 1,
#   'never': 1,
#   'new': 1,
#   'next': 1,
#   'nice': 1,
#   'ninja': 1,
#   'nra': 1,
#   'people': 1,
#   'period': 1,
#   'probably': 1,
#   'question': 1,
#   'quite': 1,
#   'r65': 1,
#   'range': 1,
#   'referred': 1,
#   'right': 1,
#   'road': 1,
#   'roads': 1,
#   'rpm': 2,
#   "rpm's": 1,
#   'says': 1,
#   'scenery': 1,
#   'seriously': 1,
#   'silly': 1,
#   'sounds': 1,
#   'speed': 3,
#   'sticker': 1,
#   'tachometer': 1,
#   'take': 2,
#   'trip': 1,
#   'trying': 1,
#   'weekends': 1,
#   'well': 1,
#   'writes': 1,
#   'yes': 1},
#  997: {'adrian': 1,
#   'approach': 1,
#   'around': 1,
#   'associates': 1,
#   'automatic': 1,
#   'avoid': 1,
#   'back': 1,
#   'benefit': 1,
#   'better': 1,
#   'bill': 1,
#   'capability': 1,
#   'case': 1,
#   'children': 1,
#   'choice': 1,
#   'client': 1,
#   'connected': 1,
#   'course': 1,
#   'deal': 1,
#   'designing': 1,
#   'directed': 1,
#   'drop': 1,
#   'easily': 1,
#   'even': 1,
#   'events': 2,
#   'eventssuch': 1,
#   'everywhere': 1,
#   'expandable': 1,
#   'expresses': 1,
#   'faster': 1,
#   'find': 1,
#   'floating': 1,
#   'forces': 1,
#   'gadget': 1,
#   'gadgets': 10,
#   'gecoprakla': 1,
#   'generate': 1,
#   'graph': 2,
#   'great': 1,
#   'handle': 1,
#   'heard': 1,
#   'inc': 1,
#   'interest': 1,
#   'internet': 1,
#   'just': 1,
#   'kayserdelftsgpslbcom': 1,
#   'layout': 1,
#   'least': 1,
#   'long': 1,
#   'longer': 1,
#   'lot': 1,
#   'make': 1,
#   'managers': 1,
#   'manages': 1,
#   'memory': 3,
#   'menus': 2,
#   'might': 1,
#   'motif': 3,
#   'motion': 1,
#   'network': 5,
#   'noticable': 1,
#   'noticed': 1,
#   'notify': 1,
#   'nye': 1,
#   "o'reilly": 1,
#   'old': 1,
#   'performance': 5,
#   'perhaps': 1,
#   'places': 1,
#   'point': 1,
#   'possible': 1,
#   'present': 1,
#   'programming': 1,
#   'pulldown': 1,
#   'pushbutton': 1,
#   'pushbuttons': 1,
#   'putting': 1,
#   'quicker': 1,
#   'really': 2,
#   'result': 2,
#   'save': 1,
#   'schlumberger': 1,
#   'server': 1,
#   'significantly': 1,
#   'simplistic': 1,
#   'start': 1,
#   'take': 1,
#   'terminals': 1,
#   'track': 1,
#   'tradeoff': 1,
#   'traffic': 1,
#   'type': 1,
#   'typically': 1,
#   'use': 2,
#   'using': 4,
#   'various': 1,
#   'way': 1,
#   'well': 1,
#   'wether': 1,
#   'widget': 1,
#   'widgets': 2,
#   'xmarc': 1,
#   'xmgraph': 2},
#  998: {'90deg': 2,
#   'also': 1,
#   'ama': 1,
#   'angle': 1,
#   'answer': 1,
#   'applied': 1,
#   'axis': 1,
#   'axle': 1,
#   'bars': 2,
#   'basically': 1,
#   'bike': 3,
#   'budweiser': 1,
#   'case': 1,
#   'causing': 1,
#   'centestandas': 1,
#   'clarke': 1,
#   'clarkebdrcbdcom': 1,
#   'counteracting': 1,
#   'countersteering': 2,
#   'david': 1,
#   'driveway': 1,
#   'effect': 1,
#   'else': 1,
#   'even': 1,
#   'first': 1,
#   'front': 1,
#   'gibbs': 1,
#   'guess': 1,
#   'gyroscopic': 1,
#   'hands': 3,
#   'head': 1,
#   'however': 1,
#   'instead': 1,
#   'just': 2,
#   'lean': 3,
#   'leaning': 1,
#   'left': 1,
#   'looking': 1,
#   'makes': 1,
#   'making': 1,
#   'open': 1,
#   'original': 1,
#   'poster': 1,
#   'quick': 1,
#   'quite': 1,
#   'remember': 1,
#   'replies': 1,
#   'rick': 2,
#   'right': 1,
#   'seem': 1,
#   'semiserious': 1,
#   'serious': 1,
#   'similar': 1,
#   'something': 1,
#   'somethingsomething': 1,
#   'somewhere': 1,
#   'steer': 1,
#   'steering': 2,
#   'suggested': 1,
#   'supply': 1,
#   'torque': 2,
#   'tried': 1,
#   'turn': 2,
#   'turns': 1,
#   'using': 1,
#   'way': 1,
#   "wheel's": 1,
#   'wiggle': 1,
#   'without': 1,
#   'work': 1,
#   'yeah': 1,
#   'yes': 1},
#  999: {'cosmoproangmar': 1,
#   'cosmoproangmaralfalfacom': 1,
#   'internet': 1,
#   'loser': 1,
#   'proline': 1,
#   'quite': 1,
#   'uucp': 1,
#   'uunetbuedualphalphaproangmarcosmo': 1},
#  1000: {'1993apr1921140622528iscnvxlmsclockheedcom': 1,
#   'according': 1,
#   'ahl': 1,
#   'amontenew': 1,
#   'anderssonobviously': 1,
#   'article': 1,
#   'becertainly': 1,
#   'benning': 1,
#   'breton': 1,
#   'buchberger': 1,
#   'canada': 1,
#   'cape': 1,
#   'case': 1,
#   'casebecause': 1,
#   'corson': 1,
#   'craig': 1,
#   'darren': 1,
#   'david': 1,
#   'decided': 1,
#   'derek': 1,
#   'doug': 1,
#   'druryharvard': 1,
#   'edmonton': 1,
#   'eligible': 1,
#   'european': 1,
#   'everyone': 1,
#   'forwards': 1,
#   'gaudreausan': 1,
#   'gerald': 1,
#   'goalies': 1,
#   'injuries': 1,
#   'interesting': 1,
#   'jeff': 1,
#   'johnsonuniv': 1,
#   'just': 1,
#   'know': 1,
#   'kovalev': 1,
#   'kravchuk': 1,
#   'late': 1,
#   'lazaroottawa': 1,
#   'like': 2,
#   'listed': 1,
#   'looks': 1,
#   'makes': 1,
#   'manson': 1,
#   'mark': 1,
#   'massively': 1,
#   'mike': 1,
#   'minnesota': 1,
#   'minnesotaduluth': 1,
#   'modanominnesota': 1,
#   'murky': 1,
#   'nagging': 1,
#   'names': 1,
#   'new': 2,
#   'news': 1,
#   'north': 1,
#   'oilers': 3,
#   'olczyknew': 1,
#   'ose': 1,
#   'outclassed': 1,
#   'paramount': 1,
#   'planteuniv': 1,
#   'play': 1,
#   'played': 1,
#   'playing': 3,
#   'playoffs': 1,
#   'pocklington': 1,
#   'podein': 2,
#   'podeinedmonton': 1,
#   'ranford': 1,
#   'rangers': 4,
#   'rob': 1,
#   'roster': 1,
#   'russiansi': 1,
#   'saccoboston': 1,
#   'sather': 1,
#   'scrooges': 1,
#   'season': 1,
#   'senators': 1,
#   'sharks': 1,
#   'shion': 1,
#   'smith': 1,
#   'spiegel': 1,
#   'spiegelsgi413msdlmsclockheedcom': 1,
#   'spring': 1,
#   'stars': 1,
#   'take': 1,
#   'team': 1,
#   'teams': 1,
#   'ted': 1,
#   'tony': 1,
#   'total': 1,
#   'tugnutt': 1,
#   'turcotte': 1,
#   'univ': 1,
#   'university': 1,
#   'usa': 1,
#   'vacation': 1,
#   'weight': 1,
#   'weightedmonton': 1,
#   'writes': 1,
#   'york': 4,
#   'zubov': 1},
#  ...}

# %%
X_train = []
for k in dictionary.keys():
    row = []
    for f in features:
        if(f in dictionary[k].keys()):
            #if word f is present in the dictionary of the document as a key, its value is copied
            #this gives us no. of occurences
            row.append(dictionary[k][f]) 
        else:
            #if not present, the no. of occurences is zero
            row.append(0)
    X_train.append(row)

# %%
X_train = np.asarray(X_train)
Y_train = np.asarray(Y_train)

# %%
list_of_words_test = []

for document in doc_test:
        list_of_words_test.append(flatten(tokenize(document)))

# %%
dictionary_test = {}
doc_num = 1
for doc_words in list_of_words_test:
    #print(doc_words)
    np_doc_words = np.asarray(doc_words)
    w, c = np.unique(np_doc_words, return_counts=True)
    dictionary_test[doc_num] = {}
    for i in range(len(w)):
        dictionary_test[doc_num][w[i]] = c[i]
    doc_num = doc_num + 1

# %%
X_test = []
for k in dictionary_test.keys():
    row = []
    for f in features:
        if(f in dictionary_test[k].keys()):
            #if word f is present in the dictionary of the document as a key, its value is copied
            #this gives us no. of occurences
            row.append(dictionary_test[k][f]) 
        else:
            #if not present, the no. of occurences is zero
            row.append(0)
    X_test.append(row)

# %%
X_test = np.asarray(X_test)
Y_test = np.asarray(Y_test)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
Y_predict = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(Y_test, Y_predict))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.62      0.75      0.68       253
#            comp.graphics       0.60      0.65      0.62       256
#  comp.os.ms-windows.misc       0.71      0.70      0.70       249
# comp.sys.ibm.pc.hardware       0.66      0.65      0.65       244
#    comp.sys.mac.hardware       0.66      0.72      0.69       269
#           comp.windows.x       0.80      0.75      0.77       240
#             misc.forsale       0.77      0.76      0.77       233
#                rec.autos       0.81      0.86      0.84       284
#          rec.motorcycles       0.80      0.92      0.86       236
#       rec.sport.baseball       0.91      0.92      0.91       236
#         rec.sport.hockey       0.97      0.94      0.95       281
#                sci.crypt       0.86      0.82      0.84       253
#          sci.electronics       0.79      0.68      0.73       233
#                  sci.med       0.90      0.79      0.84       240
#                sci.space       0.87      0.84      0.85       259
#   soc.religion.christian       0.80      0.81      0.81       248
#       talk.politics.guns       0.66      0.85      0.74       246
#    talk.politics.mideast       0.89      0.86      0.87       248
#       talk.politics.misc       0.56      0.56      0.56       231
#       talk.religion.misc       0.57      0.33      0.41       261
#
#                 accuracy                           0.76      5000
#                macro avg       0.76      0.76      0.76      5000
#             weighted avg       0.76      0.76      0.76      5000
